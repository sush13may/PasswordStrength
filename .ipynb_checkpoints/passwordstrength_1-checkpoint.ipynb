# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv',sep=',',error_bad_lines=False)
# Out:
# C:\Users\sush1\Anaconda3\envs\passwordstrength\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 2810: expected 2 fields, saw 5\nSkipping line 4641: expected 2 fields, saw 5\nSkipping line 7171: expected 2 fields, saw 5\nSkipping line 11220: expected 2 fields, saw 5\nSkipping line 13809: expected 2 fields, saw 5\nSkipping line 14132: expected 2 fields, saw 5\nSkipping line 14293: expected 2 fields, saw 5\nSkipping line 14865: expected 2 fields, saw 5\nSkipping line 17419: expected 2 fields, saw 5\nSkipping line 22801: expected 2 fields, saw 5\nSkipping line 25001: expected 2 fields, saw 5\nSkipping line 26603: expected 2 fields, saw 5\nSkipping line 26742: expected 2 fields, saw 5\nSkipping line 29702: expected 2 fields, saw 5\nSkipping line 32767: expected 2 fields, saw 5\nSkipping line 32878: expected 2 fields, saw 5\nSkipping line 35643: expected 2 fields, saw 5\nSkipping line 36550: expected 2 fields, saw 5\nSkipping line 38732: expected 2 fields, saw 5\nSkipping line 40567: expected 2 fields, saw 5\nSkipping line 40576: expected 2 fields, saw 5\nSkipping line 41864: expected 2 fields, saw 5\nSkipping line 46861: expected 2 fields, saw 5\nSkipping line 47939: expected 2 fields, saw 5\nSkipping line 48628: expected 2 fields, saw 5\nSkipping line 48908: expected 2 fields, saw 5\nSkipping line 57582: expected 2 fields, saw 5\nSkipping line 58782: expected 2 fields, saw 5\nSkipping line 58984: expected 2 fields, saw 5\nSkipping line 61518: expected 2 fields, saw 5\nSkipping line 63451: expected 2 fields, saw 5\nSkipping line 68141: expected 2 fields, saw 5\nSkipping line 72083: expected 2 fields, saw 5\nSkipping line 74027: expected 2 fields, saw 5\nSkipping line 77811: expected 2 fields, saw 5\nSkipping line 83958: expected 2 fields, saw 5\nSkipping line 85295: expected 2 fields, saw 5\nSkipping line 88665: expected 2 fields, saw 5\nSkipping line 89198: expected 2 fields, saw 5\nSkipping line 92499: expected 2 fields, saw 5\nSkipping line 92751: expected 2 fields, saw 5\nSkipping line 93689: expected 2 fields, saw 5\nSkipping line 94776: expected 2 fields, saw 5\nSkipping line 97334: expected 2 fields, saw 5\nSkipping line 102316: expected 2 fields, saw 5\nSkipping line 103421: expected 2 fields, saw 5\nSkipping line 106872: expected 2 fields, saw 5\nSkipping line 109363: expected 2 fields, saw 5\nSkipping line 110117: expected 2 fields, saw 5\nSkipping line 110465: expected 2 fields, saw 5\nSkipping line 113843: expected 2 fields, saw 5\nSkipping line 115634: expected 2 fields, saw 5\nSkipping line 121518: expected 2 fields, saw 5\nSkipping line 123692: expected 2 fields, saw 5\nSkipping line 124708: expected 2 fields, saw 5\nSkipping line 129608: expected 2 fields, saw 5\nSkipping line 133176: expected 2 fields, saw 5\nSkipping line 135532: expected 2 fields, saw 5\nSkipping line 138042: expected 2 fields, saw 5\nSkipping line 139485: expected 2 fields, saw 5\nSkipping line 140401: expected 2 fields, saw 5\nSkipping line 144093: expected 2 fields, saw 5\nSkipping line 149850: expected 2 fields, saw 5\nSkipping line 151831: expected 2 fields, saw 5\nSkipping line 158014: expected 2 fields, saw 5\nSkipping line 162047: expected 2 fields, saw 5\nSkipping line 164515: expected 2 fields, saw 5\nSkipping line 170313: expected 2 fields, saw 5\nSkipping line 171325: expected 2 fields, saw 5\nSkipping line 171424: expected 2 fields, saw 5\nSkipping line 175920: expected 2 fields, saw 5\nSkipping line 176210: expected 2 fields, saw 5\nSkipping line 183603: expected 2 fields, saw 5\nSkipping line 190264: expected 2 fields, saw 5\nSkipping line 191683: expected 2 fields, saw 5\nSkipping line 191988: expected 2 fields, saw 5\nSkipping line 195450: expected 2 fields, saw 5\nSkipping line 195754: expected 2 fields, saw 5\nSkipping line 197124: expected 2 fields, saw 5\nSkipping line 199263: expected 2 fields, saw 5\nSkipping line 202603: expected 2 fields, saw 5\nSkipping line 209960: expected 2 fields, saw 5\nSkipping line 213218: expected 2 fields, saw 5\nSkipping line 217060: expected 2 fields, saw 5\nSkipping line ...
# b'Skipping line 264626: expected 2 fields, saw 5\nSkipping line 265028: expected 2 fields, saw 5\nSkipping line 269150: expected 2 fields, saw 5\nSkipping line 271360: expected 2 fields, saw 5\nSkipping line 273975: expected 2 fields, saw 5\nSkipping line 274742: expected 2 fields, saw 5\nSkipping line 276227: expected 2 fields, saw 5\nSkipping line 279807: expected 2 fields, saw 5\nSkipping line 283425: expected 2 fields, saw 5\nSkipping line 287468: expected 2 fields, saw 5\nSkipping line 292995: expected 2 fields, saw 5\nSkipping line 293496: expected 2 fields, saw 5\nSkipping line 293735: expected 2 fields, saw 5\nSkipping line 295060: expected 2 fields, saw 5\nSkipping line 296643: expected 2 fields, saw 5\nSkipping line 296848: expected 2 fields, saw 5\nSkipping line 308926: expected 2 fields, saw 5\nSkipping line 310360: expected 2 fields, saw 5\nSkipping line 317004: expected 2 fields, saw 5\nSkipping line 318207: expected 2 fields, saw 5\nSkipping line 331783: expected 2 fields, saw 5\nSkipping line 333864: expected 2 fields, saw 5\nSkipping line 335958: expected 2 fields, saw 5\nSkipping line 336290: expected 2 fields, saw 5\nSkipping line 343526: expected 2 fields, saw 5\nSkipping line 343857: expected 2 fields, saw 5\nSkipping line 344059: expected 2 fields, saw 5\nSkipping line 348691: expected 2 fields, saw 5\nSkipping line 353446: expected 2 fields, saw 5\nSkipping line 357073: expected 2 fields, saw 5\nSkipping line 359753: expected 2 fields, saw 5\nSkipping line 359974: expected 2 fields, saw 5\nSkipping line 366534: expected 2 fields, saw 5\nSkipping line 369514: expected 2 fields, saw 5\nSkipping line 377759: expected 2 fields, saw 5\nSkipping line 379327: expected 2 fields, saw 5\nSkipping line 380769: expected 2 fields, saw 5\nSkipping line 381073: expected 2 fields, saw 5\nSkipping line 381489: expected 2 fields, saw 5\nSkipping line 386304: expected 2 fields, saw 5\nSkipping line 387635: expected 2 fields, saw 5\nSkipping line 389613: expected 2 fields, saw 5\nSkipping line 392604: expected 2 fields, saw 5\nSkipping line 393184: expected 2 fields, saw 5\nSkipping line 395530: expected 2 fields, saw 5\nSkipping line 396939: expected 2 fields, saw 5\nSkipping line 397385: expected 2 fields, saw 5\nSkipping line 397509: expected 2 fields, saw 5\nSkipping line 402902: expected 2 fields, saw 5\nSkipping line 405187: expected 2 fields, saw 5\nSkipping line 408412: expected 2 fields, saw 5\nSkipping line 419423: expected 2 fields, saw 5\nSkipping line 420962: expected 2 fields, saw 5\nSkipping line 425965: expected 2 fields, saw 5\nSkipping line 427496: expected 2 fields, saw 5\nSkipping line 438881: expected 2 fields, saw 5\nSkipping line 439776: expected 2 fields, saw 5\nSkipping line 440345: expected 2 fields, saw 5\nSkipping line 445507: expected 2 fields, saw 5\nSkipping line 445548: expected 2 fields, saw 5\nSkipping line 447184: expected 2 fields, saw 5\nSkipping line 448603: expected 2 fields, saw 5\nSkipping line 451732: expected 2 fields, saw 5\nSkipping line 458249: expected 2 fields, saw 5\nSkipping line 460274: expected 2 fields, saw 5\nSkipping line 467630: expected 2 fields, saw 5\nSkipping line 473961: expected 2 fields, saw 5\nSkipping line 476281: expected 2 fields, saw 5\nSkipping line 478010: expected 2 fields, saw 5\nSkipping line 478322: expected 2 fields, saw 5\nSkipping line 479999: expected 2 fields, saw 5\nSkipping line 480898: expected 2 fields, saw 5\nSkipping line 481688: expected 2 fields, saw 5\nSkipping line 485193: expected 2 fields, saw 5\nSkipping line 485519: expected 2 fields, saw 5\nSkipping line 486000: expected 2 fields, saw 5\nSkipping line 489063: expected 2 fields, saw 5\nSkipping line 494525: expected 2 fields, saw 5\nSkipping line 495009: expected 2 fields, saw 5\nSkipping line 501954: expected 2 fields, saw 5\nSkipping line 508035: expected 2 fields, saw 5\nSkipping line 508828: expected 2 fields, saw 5\nSkipping line 509833: expected 2 fields, saw 5\nSkipping line  ...
# b'Skipping line 525174: expected 2 fields, saw 5\nSkipping line 526251: expected 2 fields, saw 5\nSkipping line 529611: expected 2 fields, saw 5\nSkipping line 531398: expected 2 fields, saw 5\nSkipping line 534146: expected 2 fields, saw 5\nSkipping line 544954: expected 2 fields, saw 5\nSkipping line 553002: expected 2 fields, saw 5\nSkipping line 553883: expected 2 fields, saw 5\nSkipping line 553887: expected 2 fields, saw 5\nSkipping line 553915: expected 2 fields, saw 5\nSkipping line 554172: expected 2 fields, saw 5\nSkipping line 563534: expected 2 fields, saw 5\nSkipping line 565191: expected 2 fields, saw 5\nSkipping line 574108: expected 2 fields, saw 5\nSkipping line 574412: expected 2 fields, saw 5\nSkipping line 575985: expected 2 fields, saw 5\nSkipping line 580091: expected 2 fields, saw 5\nSkipping line 582682: expected 2 fields, saw 5\nSkipping line 585885: expected 2 fields, saw 5\nSkipping line 590171: expected 2 fields, saw 5\nSkipping line 591924: expected 2 fields, saw 5\nSkipping line 592515: expected 2 fields, saw 5\nSkipping line 593888: expected 2 fields, saw 5\nSkipping line 596245: expected 2 fields, saw 5\nSkipping line 607344: expected 2 fields, saw 5\nSkipping line 607633: expected 2 fields, saw 5\nSkipping line 610939: expected 2 fields, saw 5\nSkipping line 613638: expected 2 fields, saw 5\nSkipping line 615643: expected 2 fields, saw 5\nSkipping line 615901: expected 2 fields, saw 5\nSkipping line 617389: expected 2 fields, saw 5\nSkipping line 634641: expected 2 fields, saw 5\nSkipping line 635755: expected 2 fields, saw 5\nSkipping line 646243: expected 2 fields, saw 5\nSkipping line 647165: expected 2 fields, saw 5\nSkipping line 648610: expected 2 fields, saw 5\nSkipping line 648772: expected 2 fields, saw 5\nSkipping line 651833: expected 2 fields, saw 5\nSkipping line 653663: expected 2 fields, saw 5\nSkipping line 656233: expected 2 fields, saw 5\nSkipping line 656694: expected 2 fields, saw 5\nSkipping line 659783: expected 2 fields, saw 5\nSkipping line 660478: expected 2 fields, saw 5\nSkipping line 661133: expected 2 fields, saw 5\nSkipping line 661736: expected 2 fields, saw 5\nSkipping line 669827: expected 2 fields, saw 5\n'

# %%
data.head()
# Out:
#       password  strength
# 0     kzde5577         1
# 1     kino3434         1
# 2    visi7k1yr         1
# 3     megzy123         1
# 4  lamborghin1         1

# %%
data.isnull().sum()
# Out:
# password    1
# strength    0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
import seaborn as sns
sns.countplot(data['strength'])
# Out:
# C:\Users\sush1\Anaconda3\envs\passwordstrength\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='strength', ylabel='count'>

# %% [markdown]
# #### This is imbalanced dataset

# %%
X= [x for x in data['password']]
Y=[y for y in data['strength']]

# %%
print(len(X),len(Y))
print(type(X),type(Y))
# Out:
# 669639 669639
# <class 'list'> <class 'list'>

# %%
X
# Out:
# ['kzde5577',
#  'kino3434',
#  'visi7k1yr',
#  'megzy123',
#  'lamborghin1',
#  'AVYq1lDE4MgAZfNt',
#  'u6c8vhow',
#  'v1118714',
#  'universe2908',
#  'as326159',
#  'asv5o9yu',
#  '612035180tok',
#  'jytifok873',
#  'WUt9IZzE0OQ7PkNE',
#  'jerusalem393',
#  'g067057895',
#  '52558000aaa',
#  'idofo673',
#  '6975038lp',
#  'sbl571017',
#  'elyass15@ajilent-ci',
#  'intel1',
#  'klara-tershina3H',
#  'czuodhj972',
#  'faranumar91',
#  'cigicigi123',
#  '0169395484a',
#  'schalke04',
#  'prisonbreak1',
#  'asgaliu11',
#  'gaymaids1',
#  'trabajonet9',
#  'go7kew7a2po',
#  'fk9qi21m',
#  'memjan123',
#  'lsdlsd1',
#  'exitos2009',
#  'fahad123',
#  'kswa2mrv',
#  'yitbos77',
#  'juliel009',
#  'pHyqueDIyNQ8vmhb',
#  'alimagik1',
#  'yqugu927',
#  'olmaz.',
#  'hpqkoxsn5',
#  'a2531106',
#  'TyWM72UNEex8Q8Y',
#  'ejeko677',
#  'openup12',
#  'ok>bdk',
#  'tamanagung6',
#  'c3h8bkzr',
#  'patri1973',
#  'yk530mg8',
#  'bozoxik602',
#  'calcifer32',
#  'b4NbTxDEyNgG141J',
#  'd04m11',
#  'matiofox08',
#  'khmer100.03278&?><Mnb',
#  'sknq7m0',
#  'snolyuj04',
#  'kjkjkj1',
#  'bgrvl80',
#  'Iamthelegend1!',
#  'il0vey0u',
#  'obstacle25',
#  'rntprns7',
#  'gdfn76',
#  'mickael12',
#  'cesarmaio1',
#  'juliana19',
#  'kunyukbabi69',
#  'hodygid757',
#  'ga98SIzk0NwhiZaE',
#  '283671gus',
#  'jalingo1',
#  'p2share',
#  'k9b8cz6aj2',
#  'gill02',
#  'j09000',
#  '2021848709.',
#  'hayhayq2',
#  'yllime123',
#  '3vszncp4',
#  '123477889a',
#  '12345yolanda',
#  'woon12',
#  '929865yt',
#  'jonothepoop1',
#  '838188linh',
#  'kVczcljg4OA25Aeb',
#  'k1k2k3k4k5k6',
#  'poseidon2011',
#  's4m2dx9e6',
#  'xiau5ff',
#  'ns2b0727',
#  'mmm23mm',
#  'gkrqjs6',
#  'ikanez886',
#  '746xitEGiqObog',
#  'oekojWyH120063',
#  'RqsuUsDYxNgr8T40',
#  'xyws951753',
#  'elonex24',
#  'jalal123456',
#  '6tequila6',
#  'yu4cmn',
#  'ass359',
#  'icap12',
#  '2akira2',
#  'znbl5tj1',
#  '123maxbala',
#  '64959rodro',
#  'moken7',
#  'teemteem97',
#  'aquhih220',
#  'zoobike04',
#  'farrukhcse12',
#  'pato221182',
#  '10Erjrlmebup0n',
#  'pikey231',
#  'z3ro1sm',
#  'portales1',
#  'jUV4dSDQwNwPpA36',
#  'fnmsdha476',
#  'g3rappa',
#  'rogyh820',
#  'sanki1',
#  '20Dgw7TQ0OQVdly7',
#  'ldteugao6',
#  '2yz4ewwg',
#  'www32223222',
#  'yuri110995',
#  '1972vishara',
#  'warriors08',
#  'vehat387',
#  '3y6iwef2g6',
#  'RPFUOUDQwMwVW0AS',
#  'w9209640',
#  '5gzj5uf',
#  'kinga22',
#  'nicolas05',
#  '26522876p',
#  'barra23',
#  '147963asd',
#  '123net123',
#  's9830950044',
#  'denise18',
#  '2010server',
#  'p@sslng2diword',
#  'tin030201',
#  'yut0838828185',
#  '2fakjv',
#  'mazdarx7',
#  'omakiva153',
#  'alchimie79',
#  'potatobus150',
#  'damyvo114',
#  'teste10',
#  'afs34214',
#  'mohantra1',
#  'igejasy712',
#  'IjUcOtYqAwel725',
#  'wisal1234',
#  'meopvywk628',
#  '0870330135a',
#  'sarahi1628',
#  'ekufite742',
#  'polo2014',
#  'peluchin4',
#  'ginger972',
#  'demon10',
#  'tia150979',
#  's0xwym7h',
#  'puegwajy416',
#  'a0972986650',
#  'x8512514',
#  'qn5xpg3k00',
#  'finisterra1',
#  'ebacuro434',
#  '4osxw4r',
#  'nello11',
#  'sasuke4',
#  'z888888',
#  'marita1',
#  'kayal123',
#  'zgmfnwuq25',
#  'wxS2ztDk4OATjBfI',
#  'njmania114',
#  'z7zbgIDkzMQeHUd9',
#  'gandhi8513',
#  '20010509wang',
#  'wibi182d',
#  'v10rica',
#  'change201',
#  '4fqa52vecr',
#  'gozv3e5',
#  'taurofive16',
#  'q0pv0fk',
#  '215466kenyi',
#  '159951josh',
#  'cockw0mble',
#  'barboza221294',
#  'meriton23',
#  'robot425',
#  'kikeq102',
#  'ubojig109',
#  'okn9zp9o',
#  'mike09',
#  'metopelo1623',
#  'vgnfs495vp',
#  'tomas7896',
#  'tucagu356',
#  'nK0yKXTU0NQHZE2e',
#  'owote852',
#  'X9WVojjE4MgVAIiR',
#  'franczuk33',
#  'XqMB7vDMzOQocAFV',
#  'planes123',
#  'bellsuki1',
#  'samael666',
#  'koabcswzt3',
#  'pablo321159',
#  '7942vikas',
#  'edcmki90',
#  'uxyloga692',
#  'virush1n1',
#  'kyxvufl37',
#  'atigi839',
#  'gtlek',
#  'roxana1993',
#  'mustang337',
#  'caramelo9',
#  'bugatti01',
#  'frhnsvelhfr1',
#  '7mV0pKTA3MgHy8Jv',
#  'krumbul123',
#  'wycinu436',
#  'uou2dae',
#  'patty94',
#  'xW8-3w7-MFB-CKH',
#  '33kanun03',
#  'lrhxmevb620',
#  'colorado27',
#  'sbaUsoTA1OAzuevI',
#  'holamundo1',
#  'e667794c1d',
#  'kry1z9',
#  'rLLh4WDQ2OAWbDO5',
#  'djngeyut2707',
#  'kuntz80',
#  'moimoimoi9',
#  'witek1709',
#  'enziitoo1234',
#  'abizar08',
#  'shotiko18',
#  'hosna1368',
#  'ajyrew547',
#  'kenneth610',
#  '6yy6yy',
#  'ram@!sita15392',
#  'ts34a3fodh3i',
#  'a2486315',
#  'a03242241431a',
#  'a110804032',
#  'lzhzad1989',
#  'AS0130066',
#  'QWERTY0011',
#  'tahseen75',
#  'ycqtgdso3',
#  'y0unus',
#  '1katertje',
#  '1597535youssi',
#  'UF1Z2WjE5Mg26R1K',
#  't8IkFRDIxMAFV2JW',
#  'bencike7',
#  'iwaguh884',
#  'isqizkg1',
#  'josue12',
#  'mario489800',
#  'hisnipes1',
#  'xlxlxl777',
#  '0112358mayin0',
#  'sydney213',
#  'saule123',
#  'juany57',
#  'vuqADUSatAJO800',
#  'DTUQG5jU5MwmR1L9',
#  'autan88',
#  'hqh2eYjQxOQPYIsA',
#  'yy4129',
#  'mathilde54550',
#  'den019520',
#  '3CgRg8DA1NQY1iEj',
#  'aslpls2009',
#  'llahetihw1',
#  'x0004534',
#  'balamuc123',
#  'xanyrum650',
#  'jEzZXUTE3MgJ4fVk',
#  'clave08',
#  'sysoja794',
#  'xp;ysmybst',
#  'd4xQ3LjUwMQFVCYQ',
#  'ppnyadam09',
#  '1234159hero',
#  'markama10',
#  'aosmaxd0',
#  '631ihOZogELoVap',
#  'pugceya468',
#  'hasan18',
#  'cdann123',
#  'khaled12',
#  'kP82iqDMxNgBMxBP',
#  'examy624',
#  'kitty555',
#  'clyioqzgw42',
#  'weicat12',
#  'wo9aiwangyan',
#  'han19660120',
#  '1qa2ws3ed4rf',
#  'YADHJIGSAWS11',
#  'khurram_',
#  'pazzini24',
#  'afavin964',
#  'zidadoh258',
#  'webstudio8',
#  'folashade1',
#  '07dpv1127b',
#  'yu86640132',
#  '1ngaymuadong',
#  'gerardway1',
#  'sebo82',
#  'sofietou74',
#  'krishna2',
#  'acetita478',
#  '2GnTStTE4Mw4MTwv',
#  'n501iomf',
#  'cUFUSYKIPuGo024',
#  'mayur@8netinfotech',
#  'terrassa6',
#  'nokia6020',
#  'beijing168',
#  'wuzyci421',
#  'IRZA98',
#  '123nicole',
#  'oatcake87',
#  'nLIGyhTU1NQTAp6u',
#  'just1n0k',
#  'oioo9og',
#  'aio42fv',
#  'sanjaime1',
#  '0VKWoODkwOAc0pZK',
#  'gvczfel801',
#  'ryjypes139',
#  '1qa2ws3ed4r',
#  'bang6k',
#  'kyodai666',
#  'fbjurcd961',
#  'deryxi704',
#  'matiz4533',
#  'buqodym199',
#  'vietnga92',
#  'sd6x9s3s',
#  'u03kz6ez',
#  'servbot88',
#  'laedbchsx687',
#  'Staterkom20081993',
#  'cristiano7',
#  'oscar69',
#  'senghong2009',
#  'VMjz4eTkxNAbOyUU',
#  'seller1',
#  'jr88072635',
#  'JEQuloqOFUd102',
#  'Oshity07142014',
#  'GGmm26120904..',
#  'elabadmin1386',
#  'lymuvop730',
#  'ninja420',
#  '4165000yakub',
#  'seng987321',
#  'desmondkok21',
#  'qefoquf1uf',
#  '64whbrb351',
#  'jbtcnd6',
#  'd6VyrkFV6oblxNs5N8cW',
#  'taulant123',
#  'yzxwvgbdu503',
#  'tukaxo486',
#  'cerner09',
#  'tim80327',
#  'lofebop480',
#  'kdl9cl53',
#  'ebogel225',
#  'asdasdf1',
#  'clave2013',
#  'xtswdypgh936',
#  'taiga0088',
#  'pekai2004',
#  'jsm159167',
#  'byeypb2',
#  'ixehawojEPe418',
#  'graciela2',
#  'sono11',
#  'kabrito1',
#  'ocadezi586',
#  'hlQ8gDTExMQWkeda',
#  'junaid5',
#  'gutergut599',
#  'rakag279',
#  'walterivl13',
#  'zjl0kx03',
#  'kah4544875',
#  'parent777',
#  'wasanun13',
#  'may112001',
#  'purpledog1992',
#  'spl51190595',
#  'novelia21',
#  'b98nwtpriyesh',
#  'parvizrus13',
#  '16731673ir',
#  'grazi0201',
#  'killer5',
#  'viri13',
#  'adminmao888',
#  'yhwbzci130',
#  'clumsy0619',
#  'poilkjmnb987',
#  'as8594505',
#  'sebax2013',
#  'bc5e4vca',
#  'rqmswof2llb0',
#  'password0880',
#  'xf6385494',
#  'studenko123',
#  'fudijep286',
#  'yami12',
#  'sandra0547',
#  'Ju6BIMTU0MwYXtL4',
#  'ypodahe201',
#  'sw10d014',
#  'legna13',
#  '19821010a',
#  'osimeytju12',
#  'we34dar88',
#  'galoucura1',
#  'oscar2002',
#  'amandine666',
#  'aslanmarco007',
#  '9950twofour0',
#  'asakapa22',
#  'kenyu001',
#  'mashhood_afzal21087',
#  'butisugo39',
#  '4lgYVfzk1MwuzHcn',
#  'control9',
#  '4TXr5KDYxNQVTo4g',
#  '19840510kkk1',
#  '101010hadis',
#  'pilatyj280',
#  'Scipio21152030067254',
#  'uziwocy148',
#  'ahibyg892',
#  'arigato3',
#  '1991vikash',
#  'j2yj2yj2y',
#  'qwekl12',
#  'pmcm110118008',
#  '248sUqiFEJuRag',
#  'qopybuxi2',
#  'yogesh143',
#  'fr8OClDY1MAdEhHa',
#  'eVl19ADIxNAmU09N',
#  'paladinas1',
#  'upomel180',
#  'h1h2h3h4h5',
#  'urban1',
#  '238wofutUtIGyf',
#  'zedika521',
#  'satelite31',
#  '2652033abc',
#  'paulino123',
#  'PEPITO00',
#  'rrilni1747',
#  'kXzWOozU2MQ1Jv1h',
#  'zcsntdmhe098',
#  '3f5xd41l0ik7',
#  'woaini0',
#  'lollies1989',
#  'woogee04',
#  '847XagYxUHUXOW',
#  'plumilla1',
#  'mussuh4',
#  '600eretz',
#  'mega0109',
#  'webhost08',
#  '05bumd',
#  'kevin24',
#  'nhfdff2512',
#  'princ3sa',
#  'eth36498',
#  'uoaef06gfqeb',
#  'p3rf3ct0',
#  'c1brb3lt',
#  'hola45',
#  'muoaqxwc21',
#  'vardhan19',
#  'synyxyr723',
#  'zu20081965',
#  'diarie1',
#  'lqksuym982',
#  'limichan99',
#  'mdaffandi74',
#  'josef0867',
#  'olyucskw52',
#  'Herzberg@ABBOTT33656888commerce',
#  'w1ll1ams',
#  'gpc151192',
#  'faisal213',
#  'nebunule2',
#  'amoadios321',
#  'ayles2266',
#  'matha81',
#  '2863e00016',
#  'b9m7cxcgc',
#  'sergius1964',
#  '1justogax',
#  'acgyj188',
#  'X34y2CzY5MACs6kp',
#  'tspirits08',
#  'pedronha96',
#  'mark11',
#  'pastorius88',
#  'kukimuki123',
#  'keithar1',
#  'wearehis7',
#  'papasito1991',
#  'hello2104',
#  'sbnivetha123',
#  'whosdabest1',
#  'bjolgvhs69',
#  'lugerp08',
#  '1A2Z3E4R',
#  'jcav26',
#  'carla99',
#  'pass0port',
#  'itengf12',
#  'DRAGON25',
#  'groster152',
#  '01161590m',
#  'm4r4hne',
#  '123456ts',
#  '72o0yzekib4',
#  'coy29061994',
#  'overlord3127',
#  'avanakit72',
#  'Truelove19902610',
#  'popo0404',
#  'L2i2ZwTg1MQajeBm',
#  'raykuaz32',
#  'BsKbJHTY4NgesCOs',
#  'padhila30',
#  'rsuvxz08b',
#  'onurb1994',
#  'yjuqseb416',
#  'alhama11408',
#  'skoda06',
#  'taccy12',
#  'ezekiel720',
#  '23deagosto',
#  'stalucia66',
#  'cyborged69',
#  'ykfums1',
#  'iubat09',
#  'faqih82',
#  'jannia5',
#  '8g8x2su3',
#  'gedu1t1ah',
#  'jekkmoeder>',
#  'pacific52',
#  'ydd45ee',
#  'iacool99',
#  'azerty32',
#  'wbtdrieus345',
#  'kahcyxvj24',
#  'umetic21',
#  'diegote10',
#  'xve33ea',
#  'nhiannei040',
#  '2d0d7qfz',
#  'la3na4you',
#  'Jovan13lovekenthjusvan4ever',
#  'pxjwmeqyn5',
#  'macias2010',
#  'Zdyf0kjMzNQycqPx',
#  'ihana906',
#  'exusop649',
#  'aqyba894',
#  'pardalgg5',
#  'topgan22',
#  '030005qw',
#  'J0LcDWDc2NAVE8j3',
#  '52756652a',
#  'hotdog20',
#  '727nimdadre',
#  'keithcutlip99',
#  'cifinew817',
#  'jeeves123',
#  'j03l4ytr1',
#  'akucinta12',
#  'v1s2c3456',
#  'natalia12',
#  'zeitgeist1',
#  'xawipy995',
#  'zendegi2me',
#  'regodib479',
#  '5874813o',
#  'gohan2602',
#  'twil8x0',
#  'gracimir87',
#  'artom111478',
#  'BZVQZBTM1MApRV7s',
#  'jesmond26',
#  '7l1hu1xa',
#  'bghuyku37',
#  'gopal8420',
#  'wuzsadav933',
#  'numero2',
#  'patata91',
#  'iL1BEmTUyMg8YYbn',
#  'angelinajol52',
#  'poluxyj32',
#  'ilunia20',
#  'djda1203zj',
#  'bafiqkxwu0',
#  'uqilyni846',
#  'jorge1489',
#  'ci0n3exor',
#  'pr0f1s10',
#  'in595462',
#  'sha122511',
#  'RRaa--72783530081984',
#  'lovelory1',
#  'xzeyfbi495',
#  'deivid1991',
#  'ydkmujrze3',
#  'dK4dWOjM1OAPeisw',
#  'anon13',
#  'cribrot1200',
#  'x57669',
#  'luiskeko31',
#  'naseKoBUMIg295',
#  'pukiw102',
#  'koulapic33',
#  'alodise603',
#  'luthien123',
#  'hamqrc6',
#  '94311163nobp',
#  'hylefup708',
#  'maulana79',
#  'daaxvie1',
#  'azizi120583',
#  'tPGMkBjkyMg3hGzu',
#  'webhostv1t1n',
#  '123456rajput',
#  'growerz543',
#  'PSVkampioen2013',
#  'seeyouagain1',
#  'aziz098765',
#  'megdam55',
#  'MT766631',
#  'p0lp0l',
#  'julie1989',
#  'LypOJUfuLYrO477',
#  '1jancok',
#  '0847440744z',
#  'vestax25',
#  '1w2e3s4l5e6y',
#  'sun4shine76',
#  'failz0r',
#  '3clrcaevu7',
#  'utuham322',
#  'medebizu3',
#  'upyjlneg80',
#  '00J46LTAxMgME7C4',
#  'rogama69',
#  'vijay1995',
#  'o7ShLdTM0NAQRI7E',
#  'housefly74',
#  'goony01',
#  'vocal0619',
#  'pizxmwaos537',
#  'arum210684',
#  'vmdo3i',
#  'speedracer10',
#  'bambink182',
#  'evivad588',
#  '241189dumai',
#  'ab11223344',
#  'hodaq103',
#  'zb08110229',
#  'iprwxmfk84',
#  'jntjmh7',
#  'tot2531s',
#  'gkhan01',
#  'syjtdxlo81',
#  'v8porwar3',
#  'designer1206',
#  '090mca090',
#  '1k9izx',
#  'falre1524',
#  'IP1yaTDUzOQWAeI5',
#  '1ug2UKzQyMQBsleD',
#  'linhna288',
#  'satrjcrj6',
#  'ym2130104',
#  'nikolas369',
#  '000webhostcom',
#  'kate13',
#  'CabezaDePollo476',
#  'wjngzro27',
#  'mzhrmir786',
#  'kubafu77',
#  'pacman23',
#  '1245386fj',
#  'owary200',
#  'tuto0378',
#  'uzifyc502',
#  'l4torr3',
#  'ufoduvo540',
#  'sgtg5fq',
#  'yv3hpf',
#  '69556236gu',
#  'mtvwyz001',
#  'hide68',
#  'mialr325',
#  'islamasma12',
#  'bagdas2011',
#  'nndcvf1',
#  'ukyzopi369',
#  '000martin',
#  'a1233210',
#  'zoblin80',
#  'sqsn7a9',
#  '0123one47',
#  'guliotth82',
#  'smart95',
#  'elperro1',
#  'labarge1',
#  'mndzbqkv651',
#  'emufat882',
#  'trust123',
#  'yeko69',
#  '210496av',
#  'karl88',
#  'kciseba24521',
#  '27121995qw',
#  'afan520307',
#  'pap0spep0s',
#  'jbiz04h4',
#  'aan2900220',
#  'tiga33',
#  'RJXDk1zEyMwpyq0U',
#  'ilonu497',
#  'shH3t7TcyOQwKRLt',
#  'ineedyou23',
#  'gerylyx688',
#  'jj46azbo',
#  'berserk18',
#  'w1e2s3l4',
#  'korea2010',
#  'hot622204',
#  'darza6534',
#  'xie635891',
#  'midgeman8505',
#  'up8444',
#  'lancelot07',
#  'olumide1',
#  '4XakB8TkzOQWCS7Y',
#  'tollak123',
#  'herherher1',
#  'apther1940',
#  'adfbwrnt4',
#  'ixohupo747',
#  '1907sedat58',
#  'samemene@sm',
#  'mehmet4524572',
#  'Zanekurosak10%',
#  'jl440033',
#  'ewvjbilan4',
#  'hard7ware',
#  'jose30209',
#  '9h7v4z91',
#  'komorek11',
#  'gonzalez1559',
#  'YanH2kzgxMw1AsXA',
#  '123456789YO',
#  'juliana00',
#  'brokensong54',
#  'aa123000',
#  'paola1995',
#  'technofolle95',
#  'kaiden12',
#  'krowka18',
#  'sony18',
#  'peter04',
#  'jfk490giwb',
#  'copyfile09',
#  'mel008',
#  'juanito00',
#  '763EBFC5',
#  'jules2109',
#  'ivanxl33t010',
#  'BB11227122',
#  'mosad999',
#  'gjm666',
#  '8521901bzk',
#  'ziKYRyqewaxE717',
#  'yhigkenj5',
#  'daylit9',
#  '123linux',
#  '3rambywople',
#  'uuuu123',
#  '0lELoCDI1NAy8u7D',
#  'irivur594',
#  'ashaii12',
#  '029992546sj',
#  'ravens11',
#  'patrisa84',
#  'frenchtoast42',
#  'jgsxkcp639',
#  'willboss13',
#  'sabrina123',
#  'ras996633',
#  'r0cker',
#  '68a2445667',
#  'h3ndr4',
#  'nelva20',
#  'zeeshanbhai1',
#  'xx18121982',
#  'persian13223',
#  '12rabialawwal',
#  'cc71797805',
#  '12345687vini',
#  'shooting1965j',
#  'eeae14li',
#  'adriana1',
#  'lancer319',
#  'uvazyd135',
#  '1994kerr1994',
#  'ic8i6ac',
#  'chuno8704',
#  'kong0074',
#  'paul2007',
#  'oslicek00',
#  'orysex325',
#  '1satguru1',
#  'webhost0hm000',
#  'demanet147',
#  'orejuby808',
#  'bb9530',
#  '17.10.08',
#  'kashyn777',
#  'ts02521712',
#  'yilmaz070',
#  'joy112495',
#  'sex1353245',
#  'mytechoceann1',
#  'chiefwanker1',
#  'owataantena1',
#  'calung2007',
#  'szdectoj2',
#  '123charger',
#  'akfrdma813',
#  'savas123x',
#  'vertikal12',
#  'mxvurqyws5',
#  'hpw1907v',
#  'eqomu958',
#  'sucupi516',
#  '6U3xJzDE3Nggz3L1',
#  'igoj0w740luj',
#  'caitianci33',
#  'xknagqo92',
#  'meena25',
#  'ebuchkakat1',
#  'djawl1228',
#  'paws1111',
#  'lucky7777',
#  'creeped12',
#  'yudhia30',
#  'cacat123',
#  'biologie1998',
#  'cztPECjY2MQGFxnN',
#  'gombo8',
#  'SLAEgyTk0OQxphJq',
#  'q4Ger4OX7S2GZ3',
#  'paynu4pzwzw11',
#  'aliki123',
#  'ilyas789',
#  'mikrochip0',
#  'orzwnyj91',
#  'blackjack14',
#  'cotezun996',
#  'cxZLmFDYwNA1lUK9',
#  'klister1',
#  'jeckericek24',
#  'ZZw5HCjQ4OAt0AmE',
#  'jkprm45',
#  'emilly123',
#  'zmstkfka12',
#  'lolmdr1',
#  '13bola',
#  'bijou2012',
#  'evjdpxagf7',
#  'admin123',
#  'shakes@000webhost',
#  'wilian123',
#  'tksURwTM2Ng8Clsi',
#  'mpompo1',
#  'sukkur1',
#  'lizndina1',
#  'menti12061995',
#  'ekfqrga627',
#  'kb6188',
#  'ca±amo',
#  'pauramos06',
#  'y75oak7b',
#  'asoze777',
#  'darktime66',
#  'stk605tcnl',
#  'zcb1314520zxr.',
#  '1vikaspoon',
#  'uwzqoli4bce9',
#  '225arysorIgEKa',
#  'NEw5g2zM4OQQimNV',
#  'juzako131',
#  'ze6326326',
#  '10Elgei1ygybpw',
#  'ureqis557',
#  'qwe000',
#  'yesenia52',
#  'uxabeqo309',
#  'idyi5qc',
#  'rwxhzyn4',
#  'mortada7',
#  'kn217579',
#  '123963rio',
#  'before1go',
#  'nzzvfg7i9p',
#  'born1988',
#  'cacamania12',
#  'lizbeth12',
#  'dausakalys22',
#  'lolems1',
#  'nhrfkv2s12',
#  '358gohappy',
#  '25sz4a1i',
#  'taogamma21',
#  'gypz6526317',
#  'nppn1cg31nza',
#  '14sp2001',
#  'jrj7tst383lv',
#  'espinosa81',
#  'ichi7503',
#  'yamiburgo1',
#  '840GOBusEzeniwO',
#  'panama3',
#  '56985632gs',
#  'zuryvu986',
#  'jaciara25',
#  'forfun0411',
#  '1h6p8p9d',
#  'babyagie550',
#  'oti38289191',
#  'jhdd2hHg_js4dhj',
#  'pengjing10',
#  '1bismillah',
#  'b0ll0ck5',
#  'a8082855',
#  'MEXICO98',
#  'whsatou0509',
#  'komrsrmr16',
#  '4seclick8',
#  'vuwuv378',
#  'spinelsun611',
#  'tokattokat32',
#  'rUPV0njA5MQeXFbU',
#  'am221127',
#  'F48DdVDU1MgGEakE',
#  'duteje496',
#  'maylos2012',
#  'judson1833',
#  'reanimat68',
#  'nynbdj9',
#  'moocowmoo1',
#  ...]

# %%
#Vectorize the character of the all password.
#Pasword strength is judged by the placement and uses of the character, 
#Here we will vecotorize the each character inttead of the word

#Fetch each character of the password and store into the list

def charcters_ofthe_password(pwds):
    pass_char=[]
    for char in pwds:
        pass_char.append(char)
        
    return pass_char

# X_char_list=charcters_ofthe_password(X)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vector = TfidfVectorizer(tokenizer=charcters_ofthe_password)
x_tfidf = vector.fit_transform(X)

# %%
x_tfidf.shape
# Out:
# (669639, 153)

# %%
vector.vocabulary_
# Out:
# {'k': 66,
#  'z': 81,
#  'd': 59,
#  'e': 60,
#  '5': 39,
#  '7': 41,
#  'i': 64,
#  'n': 69,
#  'o': 70,
#  '3': 37,
#  '4': 38,
#  'v': 77,
#  's': 74,
#  '1': 35,
#  'y': 80,
#  'r': 73,
#  'm': 68,
#  'g': 62,
#  '2': 36,
#  'l': 67,
#  'a': 56,
#  'b': 57,
#  'h': 63,
#  'q': 72,
#  'f': 61,
#  't': 75,
#  'u': 76,
#  '6': 40,
#  'c': 58,
#  '8': 42,
#  'w': 78,
#  '9': 43,
#  '0': 34,
#  'j': 65,
#  'p': 71,
#  '@': 49,
#  '-': 31,
#  'x': 79,
#  '.': 32,
#  '>': 47,
#  '&': 26,
#  '?': 48,
#  '<': 45,
#  '!': 21,
#  ';': 44,
#  '_': 54,
#  '%': 25,
#  '±': 99,
#  '"': 22,
#  '~': 85,
#  '+': 30,
#  '^': 53,
#  '/': 33,
#  '$': 24,
#  ')': 28,
#  ' ': 20,
#  '(': 27,
#  '#': 23,
#  'ú': 138,
#  '*': 29,
#  '`': 55,
#  '{': 82,
#  '}': 84,
#  '[': 50,
#  ']': 52,
#  'þ': 142,
#  'ó': 132,
#  'ô': 133,
#  '=': 46,
#  '\\': 51,
#  '\x1c': 17,
#  '³': 101,
#  '¿': 112,
#  '\x16': 12,
#  'ò': 131,
#  '·': 105,
#  '\x1e': 19,
#  '\x19': 15,
#  '\x05': 3,
#  '\x1b': 16,
#  'å': 120,
#  '‚': 147,
#  'ä': 119,
#  'à': 115,
#  'õ': 134,
#  'ß': 114,
#  '´': 102,
#  '«': 96,
#  'ð': 129,
#  'â': 117,
#  '°': 98,
#  '|': 83,
#  '\x7f': 86,
#  '²': 100,
#  '¾': 111,
#  'ÿ': 143,
#  '\x08': 5,
#  'ê': 125,
#  'á': 116,
#  '\x10': 8,
#  '\x17': 13,
#  'º': 107,
#  '¡': 90,
#  '÷': 136,
#  'í': 126,
#  'µ': 103,
#  'ý': 141,
#  'ü': 140,
#  'û': 139,
#  'ö': 135,
#  '×': 113,
#  '¨': 95,
#  '\xa0': 89,
#  'æ': 121,
#  'è': 123,
#  'ù': 137,
#  'é': 124,
#  '\x06': 4,
#  'ñ': 130,
#  '\x81': 87,
#  '\x11': 9,
#  '—': 146,
#  '›': 151,
#  '‹': 150,
#  'œ': 144,
#  '™': 152,
#  '¦': 93,
#  '\x0f': 7,
#  'ï': 128,
#  'ç': 122,
#  '\x12': 10,
#  '\x8d': 88,
#  'î': 127,
#  '¹': 106,
#  '¶': 104,
#  '¼': 109,
#  '…': 149,
#  '\x13': 11,
#  '\x1d': 18,
#  '\x04': 2,
#  '\x0e': 6,
#  '\x02': 1,
#  '¯': 97,
#  '\x01': 0,
#  '‡': 148,
#  '¤': 92,
#  '¢': 91,
#  'ƒ': 145,
#  '§': 94,
#  'ã': 118,
#  '»': 108,
#  '\x18': 14,
#  '½': 110}

# %%
print(X[0])
print(x_tfidf[0])
# Out:
# kzde5577
#   (0, 41)	0.5913033374804587
#   (0, 39)	0.5668990475107434
#   (0, 60)	0.221689578545907
#   (0, 59)	0.2856314454344638
#   (0, 81)	0.3359256904431869
#   (0, 66)	0.2922467650108519

# %%
type(x_tfidf)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
x_tfidf[0].shape
# Out:
# (1, 153)

# %%
feature_name = vector.get_feature_names_out()

#get tfidf vector for first document
first_doc=x_tfidf[0]
first_vect=pd.DataFrame(first_doc.T.todense(), index=feature_name, columns=['tfidf'])
first_vect.sort_values(by='tfidf', ascending=False)
# Out:
#        tfidf
# 7   0.591303
# 5   0.566899
# z   0.335926
# k   0.292247
# d   0.285631
# ..       ...
# \   0.000000
# ]   0.000000
# ^   0.000000
# _   0.000000
# ™   0.000000
#
# [153 rows x 1 columns]

# %%
#!pip install imbalanced-learn

# %%
## Divide the dataset into train, test plit
from sklearn.model_selection import train_test_split

xtrain,xtest, ytrain,ytest=train_test_split(x_tfidf,Y, random_state=10, test_size=0.25)
print(xtrain.shape,xtest.shape,len(ytrain),len(ytest))
# Out:
# (502229, 153) (167410, 153) 502229 167410

# %%
from sklearn.linear_model import LogisticRegression

lgr = LogisticRegression(multi_class='ovr',max_iter=2000)
lgr.fit(xtrain,ytrain)
# Out:
# LogisticRegression(max_iter=2000, multi_class='ovr')

# %%
ytrain_pred= lgr.predict(xtrain)
print(lgr.score(xtrain,ytrain))
# Out:
# 0.8121753224126843

# %%
ytest_pred=lgr.predict(xtest)
print(lgr.score(xtest,ytest))
# Out:
# 0.8111283674810346

# %%
lgr_mult = LogisticRegression(multi_class='multinomial',max_iter=2000)
lgr_mult.fit(xtrain,ytrain)
# Out:
# LogisticRegression(max_iter=2000, multi_class='multinomial')

# %%
print(lgr_mult.score(xtest,ytest))
# Out:
# 0.8182665312705334

# %%
input_test=input("Enter Password to test the stregnthness.")
if input_test=='':
    input_test='abcedefgh'
input_password=np.array([input_test])
feed_pwd= vector.transform(input_password)
pred = lgr_mult.predict(feed_pwd)
print(pred)
# Out:
# Enter Password to test the stregnthness.hsfdkj43jhfkj34
# [1]

# %% [markdown]
# ##### XGBoost Algorith

# %%
from xgboost import XGBClassifier

# %%
#!pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (0.2.5)
# Requirement already satisfied: cloudpickle in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from hyperopt) (2.0.0)
# Requirement already satisfied: numpy in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from hyperopt) (1.21.2)
# Requirement already satisfied: tqdm in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from hyperopt) (4.62.3)
# Requirement already satisfied: scipy in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from hyperopt) (1.7.1)
# Requirement already satisfied: future in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from hyperopt) (0.18.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from hyperopt) (2.6.3)
# Requirement already satisfied: six in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: colorama in c:\users\sush1\anaconda3\envs\passwordstrength\lib\site-packages (from tqdm->hyperopt) (0.4.4)

# %%
from hyperopt import hp

space={'max_depth':hp.quniform("max_depth", 3, 18,2),
       'gamma': hp.uniform('gamma',1,9),
       'reg_alpha': hp.quniform('reg_alpha', 40, 180,1),
       'reg_lambda': hp.uniform('reg_lambda',0,1),
       'colsample_bytree': hp.uniform('colsample_bytree', 0.5,1),
       'min_child_Weight': hp.quniform('min_Child_weight', 0,10,1),
       'n_estimators': 100),
       'seed':0
    
}
# Out:
#   File "C:\Users\sush1\AppData\Local\Temp/ipykernel_7616/1327060012.py", line 9
#     'n_estimators': 100),
#                        ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '{' on line 3

# %%
from sklearn.metrics import accuracy_score, classification_report
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe 
def objective(space):
    clf=XGBClassifier(n_estimators=space['n_estimators'],
                     max_depth=int(space['max_depth']),
                     gamma=space['gamma'],
                     reg_alpha=int(space['reg_alpha']),
                     min_child_weight=int(space['min_child_Weight']),
                     colsample_bytree=int(space['colsample_bytree']),
                     reg_lambda=space['reg_lambda'], use_label_encoder=False)
    
    evaluation=[(xtrain,ytrain),(xtest,ytest)]
    clf.fit(xtrain,ytrain,
           eval_set=evaluation, eval_metric="auc",
            early_stopping_rounds=10,verbose=1)
    pred= clf.predict(xtest)
    accuracy=accuracy_score(ytest, pred)
    print('Accuracy Score:', accuracy)
    print('classification REport:')
    print(classification_report(ytest, pred))
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
# Out:
# [0]	validation_0-auc:0.68917	validation_1-auc:0.68727
# [1]	validation_0-auc:0.78453	validation_1-auc:0.78257
# [2]	validation_0-auc:0.80955	validation_1-auc:0.80789
# [3]	validation_0-auc:0.80931	validation_1-auc:0.80767
# [4]	validation_0-auc:0.83046	validation_1-auc:0.82895
# [5]	validation_0-auc:0.84521	validation_1-auc:0.84293
# [6]	validation_0-auc:0.86866	validation_1-auc:0.86498
# [7]	validation_0-auc:0.86840	validation_1-auc:0.86471
# [8]	validation_0-auc:0.86752	validation_1-auc:0.86382
# [9]	validation_0-auc:0.86738	validation_1-auc:0.86367
# [10]	validation_0-auc:0.86742	validation_1-auc:0.86367
# [11]	validation_0-auc:0.86733	validation_1-auc:0.86358
# [12]	validation_0-auc:0.87333	validation_1-auc:0.86968
# [13]	validation_0-auc:0.87212	validation_1-auc:0.86849
# [14]	validation_0-auc:0.87641	validation_1-auc:0.87304
# [15]	validation_0-auc:0.87639	validation_1-auc:0.87302
# [16]	validation_0-auc:0.88136	validation_1-auc:0.87834
# [17]	validation_0-auc:0.88135	validation_1-auc:0.87832
# [18]	validation_0-auc:0.88690	validation_1-auc:0.88383
# [19]	validation_0-auc:0.89024	validation_1-auc:0.88733
# [20]	validation_0-auc:0.89318	validation_1-auc:0.89014
# [21]	validation_0-auc:0.89345	validation_1-auc:0.89036
# [22]	validation_0-auc:0.89344	validation_1-auc:0.89035
# [23]	validation_0-auc:0.89608	validation_1-auc:0.89301
# [24]	validation_0-auc:0.89608	validation_1-auc:0.89300
# [25]	validation_0-auc:0.89630	validation_1-auc:0.89341
# [26]	validation_0-auc:0.89629	validation_1-auc:0.89340
# [27]	validation_0-auc:0.89629	validation_1-auc:0.89340
# [28]	validation_0-auc:0.90026	validation_1-auc:0.89734
# [29]	validation_0-auc:0.90025	validation_1-auc:0.89734
# [30]	validation_0-auc:0.90025	validation_1-auc:0.89733
# [31]	validation_0-auc:0.90025	validation_1-auc:0.89733
# [32]	validation_0-auc:0.90491	validation_1-auc:0.90211
# [33]	validation_0-auc:0.90490	validation_1-auc:0.90210
# [34]	validation_0-auc:0.90490	validation_1-auc:0.90210
# [35]	validation_0-auc:0.90489	validation_1-auc:0.90209
# [36]	validation_0-auc:0.90636	validation_1-auc:0.90354
# [37]	validation_0-auc:0.90671	validation_1-auc:0.90387
# [38]	validation_0-auc:0.91001	validation_1-auc:0.90703
# [39]	validation_0-auc:0.91136	validation_1-auc:0.90842
# [40]	validation_0-auc:0.91154	validation_1-auc:0.90871
# [41]	validation_0-auc:0.91236	validation_1-auc:0.90966
# [42]	validation_0-auc:0.91240	validation_1-auc:0.90972
# [43]	validation_0-auc:0.91241	validation_1-auc:0.90974
# [44]	validation_0-auc:0.91241	validation_1-auc:0.90974
# [45]	validation_0-auc:0.91241	validation_1-auc:0.90974
# [46]	validation_0-auc:0.91279	validation_1-auc:0.91011
# [47]	validation_0-auc:0.91744	validation_1-auc:0.91480
# [48]	validation_0-auc:0.91960	validation_1-auc:0.91704
# [49]	validation_0-auc:0.92110	validation_1-auc:0.91852
# [50]	validation_0-auc:0.92102	validation_1-auc:0.91838
# [51]	validation_0-auc:0.92327	validation_1-auc:0.92065
# [52]	validation_0-auc:0.92263	validation_1-auc:0.91999
# [53]	validation_0-auc:0.92296	validation_1-auc:0.92035
# [54]	validation_0-auc:0.92296	validation_1-auc:0.92034
# [55]	validation_0-auc:0.92350	validation_1-auc:0.92089
# [56]	validation_0-auc:0.92417	validation_1-auc:0.92167
# [57]	validation_0-auc:0.92442	validation_1-auc:0.92193
# [58]	validation_0-auc:0.92450	validation_1-auc:0.92197
# [59]	validation_0-auc:0.92450	validation_1-auc:0.92197
# [60]	validation_0-auc:0.92450	validation_1-auc:0.92197
# [61]	validation_0-auc:0.92455	validation_1-auc:0.92205
# [62]	validation_0-auc:0.92537	validation_1-auc:0.92291
# [63]	validation_0-auc:0.92567	validation_1-auc:0.92314
# [64]	validation_0-auc:0.92644	validation_1-auc:0.92396
# [65]	validation_0-auc:0.92644	validation_1-auc:0.92395
# [66]	validation_0-auc:0.92681	validation_1-auc:0.92427
# [67]	validation_0-auc:0.92999	validation_1-auc:0.92749
# [68]	validation_0-auc:0.92998	validation_1-auc:0.92749
# [69]	validation_0-auc:0.93022	validation_1-auc:0.92775
# [70]	validation_0-auc:0.93022	validation_1-auc:0.92775
# [71]	validation_0-auc:0.93132	validation_1-auc:0.92889
# [72]	validation_0-auc:0.93132	validation_1-auc:0.92889
# [73]	validation_0-auc:0.93204	validation_1-auc:0.92964
# [74]	validation_0-auc:0.93222	validation_1-auc:0.92988
# [75]	validation_0-auc:0.93257	validation_1-auc:0.93038
# [76]	validation_0-auc:0.93257	validation_1-auc:0.93039
# [77]	validation_0-auc:0.93290	validation_1-auc:0.93075
# [78]	validation_0-auc:0.93383	validation_1-auc:0.93172
# [79]	validation_0-auc:0.93383	validation_1-auc:0.93171
# [80]	validation_0-auc:0.93383	validation_1-auc:0.93171
# [81]	validation_0-auc:0.93450	validation_1-auc:0.93242
# [82]	validation_0-auc:0.93453	validation_1-auc:0.93248
# [83]	validation_0-auc:0.93479	validation_1-auc:0.93281
# [84]	validation_0-auc:0.93479	validation_1-auc:0.93281
# [85]	validation_0-auc:0.93532	validation_1-auc:0.93336
# [86]	validation_0-auc:0.93532	validation_1-auc:0.93336
# [87]	validation_0-auc:0.93551	validation_1-auc:0.93360
# [88]	validation_0-auc:0.93570	validation_1-auc:0.93382
# [89]	validation_0-auc:0.93566	validation_1-auc:0.93379
# [90]	validation_0-auc:0.93566	validation_1-auc:0.93379
# [91]	validation_0-auc:0.93597	validation_1-auc:0.93409
# [92]	validation_0-auc:0.93597	validation_1-auc:0.93409
# [93]	validation_0-auc:0.93600	validation_1-auc:0.93413
# [94]	validation_0-auc:0.93637	validation_1-auc:0.93448
# [95]	validation_0-auc:0.93658	validation_1-auc:0.93468
# [96]	validation_0-auc:0.93653	validation_1-auc:0.93465
# [97]	validation_0-auc:0.93653	validation_1-auc:0.93465
# [98]	validation_0-auc:0.93656	validation_1-auc:0.93469
# [99]	validation_0-auc:0.93664	validation_1-auc:0.93474
# [100]	validation_0-auc:0.93756	validation_1-auc:0.93571
# [101]	validation_0-auc:0.93772	validation_1-auc:0.93586
# [102]	validation_0-auc:0.93800	validation_1-auc:0.93616
# [103]	validation_0-auc:0.93804	validation_1-auc:0.93617
# [104]	validation_0-auc:0.93814	validation_1-auc:0.93627
# [105]	validation_0-auc:0.93814	validation_1-auc:0.93627
# [106]	validation_0-auc:0.93859	validation_1-auc:0.93672
# [107]	validation_0-auc:0.93859	validation_1-auc:0.93672
# [108]	validation_0-auc:0.93859	validation_1-auc:0.93672
# [109]	validation_0-auc:0.93859	validation_1-auc:0.93672
# [110]	validation_0-auc:0.93885	validation_1-auc:0.93694
# [111]	validation_0-auc:0.93885	validation_1-auc:0.93694
# [112]	validation_0-auc:0.93885	validation_1-auc:0.93694
# [113]	validation_0-auc:0.93900	validation_1-auc:0.93704
# [114]	validation_0-auc:0.93900	validation_1-auc:0.93704
# [115]	validation_0-auc:0.93900	validation_1-auc:0.93705
# [116]	validation_0-auc:0.93909	validation_1-auc:0.93713
# [117]	validation_0-auc:0.93906	validation_1-auc:0.93711
# [118]	validation_0-auc:0.93906	validation_1-auc:0.93711
# [119]	validation_0-auc:0.93911	validation_1-auc:0.93714
# [120]	validation_0-auc:0.93941	validation_1-auc:0.93750
# [121]	validation_0-auc:0.93966	validation_1-auc:0.93777
# [122]	validation_0-auc:0.93966	validation_1-auc:0.93777
# [123]	validation_0-auc:0.93966	validation_1-auc:0.93777
# [124]	validation_0-auc:0.93966	validation_1-auc:0.93777
# [125]	validation_0-auc:0.93967	validation_1-auc:0.93776
# [126]	validation_0-auc:0.93986	validation_1-auc:0.93796
# [127]	validation_0-auc:0.93986	validation_1-auc:0.93795
# [128]	validation_0-auc:0.93987	validation_1-auc:0.93797
# [129]	validation_0-auc:0.93987	validation_1-auc:0.93797
# Accuracy Score:
# 0.8758198434979989
# classification REport:
#               precision    recall  f1-score   support
#
#            0       0.80      0.36      0.50     22646
#            1       0.87      0.98      0.92    123982
#            2       0.94      0.84      0.88     20782
#
#     accuracy                           0.88    167410
#    macro avg       0.87      0.72      0.77    167410
# weighted avg       0.87      0.88      0.86    167410
#
# [0]	validation_0-auc:0.69138	validation_1-auc:0.68987
# [1]	validation_0-auc:0.78626	validation_1-auc:0.78436
# [2]	validation_0-auc:0.81137	validation_1-auc:0.80981
# [3]	validation_0-auc:0.81117	validation_1-auc:0.80962
# [4]	validation_0-auc:0.83191	validation_1-auc:0.83034
# [5]	validation_0-auc:0.84744	validation_1-auc:0.84521
# [6]	validation_0-auc:0.87230	validation_1-auc:0.86843
# [7]	validation_0-auc:0.87204	validation_1-auc:0.86818
# [8]	validation_0-auc:0.87044	validation_1-auc:0.86654
# [9]	validation_0-auc:0.87031	validation_1-auc:0.86641
# [10]	validation_0-auc:0.87043	validation_1-auc:0.86648
# [11]	validation_0-auc:0.87035	validation_1-auc:0.86640
# [12]	validation_0-auc:0.87641	validation_1-auc:0.87262
# [13]	validation_0-auc:0.87470	validation_1-auc:0.87087
# [14]	validation_0-auc:0.87955	validation_1-auc:0.87587
# [15]	validation_0-auc:0.87953	validation_1-auc:0.87584
# [16]	validation_0-auc:0.88551	validation_1-auc:0.88206
# [17]	validation_0-auc:0.88549	validation_1-auc:0.88204
# [18]	validation_0-auc:0.89131	validation_1-auc:0.88790
# [19]	validation_0-auc:0.89491	validation_1-auc:0.89158
# [20]	validation_0-auc:0.89775	validation_1-auc:0.89441
# [21]	validation_0-auc:0.89805	validation_1-auc:0.89465
# [22]	validation_0-auc:0.89804	validation_1-auc:0.89463
# [23]	validation_0-auc:0.90065	validation_1-auc:0.89723
# [24]	validation_0-auc:0.90065	validation_1-auc:0.89723
# [25]	validation_0-auc:0.90080	validation_1-auc:0.89754
# [26]	validation_0-auc:0.90080	validation_1-auc:0.89753
# [27]	validation_0-auc:0.90079	validation_1-auc:0.89751
# [28]	validation_0-auc:0.90515	validation_1-auc:0.90178
# [29]	validation_0-auc:0.90514	validation_1-auc:0.90177
# [30]	validation_0-auc:0.90514	validation_1-auc:0.90177
# [31]	validation_0-auc:0.90514	validation_1-auc:0.90177
# [32]	validation_0-auc:0.90943	validation_1-auc:0.90616
# [33]	validation_0-auc:0.90944	validation_1-auc:0.90616
# [34]	validation_0-auc:0.90944	validation_1-auc:0.90616
# [35]	validation_0-auc:0.90943	validation_1-auc:0.90617
# [36]	validation_0-auc:0.91101	validation_1-auc:0.90781
# [37]	validation_0-auc:0.91140	validation_1-auc:0.90819
# [38]	validation_0-auc:0.91456	validation_1-auc:0.91126
# [39]	validation_0-auc:0.91588	validation_1-auc:0.91268
# [40]	validation_0-auc:0.91638	validation_1-auc:0.91328
# [41]	validation_0-auc:0.91727	validation_1-auc:0.91428
# [42]	validation_0-auc:0.91733	validation_1-auc:0.91436
# [43]	validation_0-auc:0.91737	validation_1-auc:0.91440
# [44]	validation_0-auc:0.91737	validation_1-auc:0.91440
# [45]	validation_0-auc:0.91737	validation_1-auc:0.91440
# [46]	validation_0-auc:0.91787	validation_1-auc:0.91490
# [47]	validation_0-auc:0.92229	validation_1-auc:0.91937
# [48]	validation_0-auc:0.92428	validation_1-auc:0.92151
# [49]	validation_0-auc:0.92553	validation_1-auc:0.92277
# [50]	validation_0-auc:0.92552	validation_1-auc:0.92273
# [51]	validation_0-auc:0.92769	validation_1-auc:0.92493
# [52]	validation_0-auc:0.92696	validation_1-auc:0.92416
# [53]	validation_0-auc:0.92743	validation_1-auc:0.92465
# [54]	validation_0-auc:0.92743	validation_1-auc:0.92464
# [55]	validation_0-auc:0.92796	validation_1-auc:0.92525
# [56]	validation_0-auc:0.92863	validation_1-auc:0.92598
# [57]	validation_0-auc:0.92894	validation_1-auc:0.92630
# [58]	validation_0-auc:0.92927	validation_1-auc:0.92655
# [59]	validation_0-auc:0.92927	validation_1-auc:0.92655
# [60]	validation_0-auc:0.92927	validation_1-auc:0.92654
# [61]	validation_0-auc:0.92922	validation_1-auc:0.92651
# [62]	validation_0-auc:0.93005	validation_1-auc:0.92739
# [63]	validation_0-auc:0.93053	validation_1-auc:0.92773
# [64]	validation_0-auc:0.93145	validation_1-auc:0.92874
# [65]	validation_0-auc:0.93145	validation_1-auc:0.92874
# [66]	validation_0-auc:0.93195	validation_1-auc:0.92918
# [67]	validation_0-auc:0.93486	validation_1-auc:0.93217
# [68]	validation_0-auc:0.93486	validation_1-auc:0.93217
# [69]	validation_0-auc:0.93509	validation_1-auc:0.93242
# [70]	validation_0-auc:0.93509	validation_1-auc:0.93242
# [71]	validation_0-auc:0.93623	validation_1-auc:0.93363
# [72]	validation_0-auc:0.93623	validation_1-auc:0.93363
# [73]	validation_0-auc:0.93710	validation_1-auc:0.93458
# [74]	validation_0-auc:0.93729	validation_1-auc:0.93481
# [75]	validation_0-auc:0.93761	validation_1-auc:0.93520
# [76]	validation_0-auc:0.93761	validation_1-auc:0.93520
# [77]	validation_0-auc:0.93783	validation_1-auc:0.93545
# [78]	validation_0-auc:0.93858	validation_1-auc:0.93624
# [79]	validation_0-auc:0.93858	validation_1-auc:0.93624
# [80]	validation_0-auc:0.93858	validation_1-auc:0.93624
# [81]	validation_0-auc:0.93943	validation_1-auc:0.93712
# [82]	validation_0-auc:0.93945	validation_1-auc:0.93717
# [83]	validation_0-auc:0.93976	validation_1-auc:0.93753
# [84]	validation_0-auc:0.93976	validation_1-auc:0.93753
# [85]	validation_0-auc:0.94033	validation_1-auc:0.93812
# [86]	validation_0-auc:0.94034	validation_1-auc:0.93812
# [87]	validation_0-auc:0.94059	validation_1-auc:0.93837
# [88]	validation_0-auc:0.94090	validation_1-auc:0.93864
# [89]	validation_0-auc:0.94079	validation_1-auc:0.93852
# [90]	validation_0-auc:0.94079	validation_1-auc:0.93852
# [91]	validation_0-auc:0.94117	validation_1-auc:0.93890
# [92]	validation_0-auc:0.94118	validation_1-auc:0.93890
# [93]	validation_0-auc:0.94122	validation_1-auc:0.93896
# [94]	validation_0-auc:0.94150	validation_1-auc:0.93922
# [95]	validation_0-auc:0.94179	validation_1-auc:0.93950
# [96]	validation_0-auc:0.94176	validation_1-auc:0.93946
# [97]	validation_0-auc:0.94183	validation_1-auc:0.93956
# [98]	validation_0-auc:0.94185	validation_1-auc:0.93958
# [99]	validation_0-auc:0.94197	validation_1-auc:0.93965
# [100]	validation_0-auc:0.94293	validation_1-auc:0.94066
# [101]	validation_0-auc:0.94309	validation_1-auc:0.94079
# [102]	validation_0-auc:0.94341	validation_1-auc:0.94107
# [103]	validation_0-auc:0.94338	validation_1-auc:0.94106
# [104]	validation_0-auc:0.94349	validation_1-auc:0.94115
# [105]	validation_0-auc:0.94349	validation_1-auc:0.94115
# [106]	validation_0-auc:0.94422	validation_1-auc:0.94189
# [107]	validation_0-auc:0.94424	validation_1-auc:0.94190
# [108]	validation_0-auc:0.94424	validation_1-auc:0.94190
# [109]	validation_0-auc:0.94424	validation_1-auc:0.94190
# Accuracy Score:
# 0.8757720566274416
# classification REport:
#               precision    recall  f1-score   support
#
#            0       0.81      0.35      0.49     22646
#            1       0.87      0.98      0.92    123982
#            2       0.94      0.84      0.89     20782
#
#     accuracy                           0.88    167410
#    macro avg       0.87      0.72      0.77    167410
# weighted avg       0.87      0.88      0.86    167410
#
# [0]	validation_0-auc:0.68924	validation_1-auc:0.68738
# [1]	validation_0-auc:0.78366	validation_1-auc:0.78184
# [2]	validation_0-auc:0.80925	validation_1-auc:0.80772
# [3]	validation_0-auc:0.80888	validation_1-auc:0.80733
# [4]	validation_0-auc:0.83032	validation_1-auc:0.82879
# [5]	validation_0-auc:0.84613	validation_1-auc:0.84381
# [6]	validation_0-auc:0.86987	validation_1-auc:0.86603
# [7]	validation_0-auc:0.86960	validation_1-auc:0.86574
# [8]	validation_0-auc:0.86852	validation_1-auc:0.86468
# [9]	validation_0-auc:0.86837	validation_1-auc:0.86454
# [10]	validation_0-auc:0.86843	validation_1-auc:0.86457
# [11]	validation_0-auc:0.86835	validation_1-auc:0.86449
# [12]	validation_0-auc:0.87428	validation_1-auc:0.87055
# [13]	validation_0-auc:0.87297	validation_1-auc:0.86925
# [14]	validation_0-auc:0.87737	validation_1-auc:0.87393
# [15]	validation_0-auc:0.87733	validation_1-auc:0.87389
# [16]	validation_0-auc:0.88219	validation_1-auc:0.87905
# [17]	validation_0-auc:0.88217	validation_1-auc:0.87903
# [18]	validation_0-auc:0.88808	validation_1-auc:0.88492
# [19]	validation_0-auc:0.89178	validation_1-auc:0.88872
# [20]	validation_0-auc:0.89465	validation_1-auc:0.89149
# [21]	validation_0-auc:0.89492	validation_1-auc:0.89170
# [22]	validation_0-auc:0.89491	validation_1-auc:0.89169
# [23]	validation_0-auc:0.89749	validation_1-auc:0.89430
# [24]	validation_0-auc:0.89749	validation_1-auc:0.89430
# [25]	validation_0-auc:0.89764	validation_1-auc:0.89463
# [26]	validation_0-auc:0.89763	validation_1-auc:0.89463
# [27]	validation_0-auc:0.89763	validation_1-auc:0.89462
# [28]	validation_0-auc:0.90174	validation_1-auc:0.89869
# [29]	validation_0-auc:0.90173	validation_1-auc:0.89868
# [30]	validation_0-auc:0.90173	validation_1-auc:0.89868
# [31]	validation_0-auc:0.90173	validation_1-auc:0.89868
# [32]	validation_0-auc:0.90612	validation_1-auc:0.90312
# [33]	validation_0-auc:0.90612	validation_1-auc:0.90312
# [34]	validation_0-auc:0.90612	validation_1-auc:0.90311
# [35]	validation_0-auc:0.90611	validation_1-auc:0.90311
# [36]	validation_0-auc:0.90761	validation_1-auc:0.90461
# [37]	validation_0-auc:0.90800	validation_1-auc:0.90498
# [38]	validation_0-auc:0.91120	validation_1-auc:0.90805
# [39]	validation_0-auc:0.91252	validation_1-auc:0.90943
# [40]	validation_0-auc:0.91278	validation_1-auc:0.90981
# [41]	validation_0-auc:0.91356	validation_1-auc:0.91073
# [42]	validation_0-auc:0.91360	validation_1-auc:0.91079
# [43]	validation_0-auc:0.91362	validation_1-auc:0.91081
# [44]	validation_0-auc:0.91362	validation_1-auc:0.91081
# [45]	validation_0-auc:0.91361	validation_1-auc:0.91081
# [46]	validation_0-auc:0.91402	validation_1-auc:0.91119
# [47]	validation_0-auc:0.91858	validation_1-auc:0.91579
# [48]	validation_0-auc:0.92073	validation_1-auc:0.91801
# [49]	validation_0-auc:0.92227	validation_1-auc:0.91954
# [50]	validation_0-auc:0.92221	validation_1-auc:0.91945
# [51]	validation_0-auc:0.92444	validation_1-auc:0.92172
# [52]	validation_0-auc:0.92372	validation_1-auc:0.92100
# [53]	validation_0-auc:0.92406	validation_1-auc:0.92137
# [54]	validation_0-auc:0.92405	validation_1-auc:0.92136
# [55]	validation_0-auc:0.92458	validation_1-auc:0.92189
# [56]	validation_0-auc:0.92524	validation_1-auc:0.92266
# [57]	validation_0-auc:0.92549	validation_1-auc:0.92292
# [58]	validation_0-auc:0.92565	validation_1-auc:0.92302
# [59]	validation_0-auc:0.92565	validation_1-auc:0.92302
# [60]	validation_0-auc:0.92565	validation_1-auc:0.92301
# [61]	validation_0-auc:0.92571	validation_1-auc:0.92308
# [62]	validation_0-auc:0.92657	validation_1-auc:0.92398
# [63]	validation_0-auc:0.92689	validation_1-auc:0.92424
# [64]	validation_0-auc:0.92768	validation_1-auc:0.92510
# [65]	validation_0-auc:0.92767	validation_1-auc:0.92509
# [66]	validation_0-auc:0.92807	validation_1-auc:0.92543
# [67]	validation_0-auc:0.93120	validation_1-auc:0.92862
# [68]	validation_0-auc:0.93120	validation_1-auc:0.92862
# [69]	validation_0-auc:0.93142	validation_1-auc:0.92887
# [70]	validation_0-auc:0.93142	validation_1-auc:0.92887
# [71]	validation_0-auc:0.93259	validation_1-auc:0.93013
# [72]	validation_0-auc:0.93259	validation_1-auc:0.93013
# [73]	validation_0-auc:0.93346	validation_1-auc:0.93100
# [74]	validation_0-auc:0.93366	validation_1-auc:0.93125
# [75]	validation_0-auc:0.93400	validation_1-auc:0.93173
# [76]	validation_0-auc:0.93400	validation_1-auc:0.93173
# [77]	validation_0-auc:0.93429	validation_1-auc:0.93207
# [78]	validation_0-auc:0.93519	validation_1-auc:0.93301
# [79]	validation_0-auc:0.93519	validation_1-auc:0.93301
# [80]	validation_0-auc:0.93519	validation_1-auc:0.93301
# [81]	validation_0-auc:0.93593	validation_1-auc:0.93378
# [82]	validation_0-auc:0.93599	validation_1-auc:0.93388
# [83]	validation_0-auc:0.93626	validation_1-auc:0.93422
# [84]	validation_0-auc:0.93626	validation_1-auc:0.93422
# [85]	validation_0-auc:0.93687	validation_1-auc:0.93482
# [86]	validation_0-auc:0.93687	validation_1-auc:0.93483
# [87]	validation_0-auc:0.93705	validation_1-auc:0.93507
# [88]	validation_0-auc:0.93724	validation_1-auc:0.93529
# [89]	validation_0-auc:0.93715	validation_1-auc:0.93519
# [90]	validation_0-auc:0.93715	validation_1-auc:0.93519
# [91]	validation_0-auc:0.93744	validation_1-auc:0.93548
# [92]	validation_0-auc:0.93744	validation_1-auc:0.93548
# [93]	validation_0-auc:0.93747	validation_1-auc:0.93552
# [94]	validation_0-auc:0.93772	validation_1-auc:0.93578
# [95]	validation_0-auc:0.93801	validation_1-auc:0.93605
# [96]	validation_0-auc:0.93791	validation_1-auc:0.93597
# [97]	validation_0-auc:0.93791	validation_1-auc:0.93597
# [98]	validation_0-auc:0.93794	validation_1-auc:0.93600
# [99]	validation_0-auc:0.93803	validation_1-auc:0.93605
# [100]	validation_0-auc:0.93901	validation_1-auc:0.93705
# [101]	validation_0-auc:0.93915	validation_1-auc:0.93720
# [102]	validation_0-auc:0.93950	validation_1-auc:0.93751
# [103]	validation_0-auc:0.93945	validation_1-auc:0.93746
# [104]	validation_0-auc:0.93954	validation_1-auc:0.93756
# [105]	validation_0-auc:0.93954	validation_1-auc:0.93756
# [106]	validation_0-auc:0.94011	validation_1-auc:0.93814
# [107]	validation_0-auc:0.94011	validation_1-auc:0.93813
# [108]	validation_0-auc:0.94011	validation_1-auc:0.93813
# [109]	validation_0-auc:0.94011	validation_1-auc:0.93813
# [110]	validation_0-auc:0.94036	validation_1-auc:0.93835
# [111]	validation_0-auc:0.94036	validation_1-auc:0.93835
# [112]	validation_0-auc:0.94036	validation_1-auc:0.93835
# [113]	validation_0-auc:0.94049	validation_1-auc:0.93846
# [114]	validation_0-auc:0.94049	validation_1-auc:0.93846
# [115]	validation_0-auc:0.94049	validation_1-auc:0.93846
# [116]	validation_0-auc:0.94058	validation_1-auc:0.93854
# [117]	validation_0-auc:0.94056	validation_1-auc:0.93854
# [118]	validation_0-auc:0.94056	validation_1-auc:0.93854
# [119]	validation_0-auc:0.94073	validation_1-auc:0.93871
# Accuracy Score:
# 0.8751149871572785
# classification REport:
#               precision    recall  f1-score   support
#
#            0       0.81      0.35      0.49     22646
#            1       0.87      0.98      0.92    123982
#            2       0.94      0.83      0.88     20782
#
#     accuracy                           0.88    167410
#    macro avg       0.87      0.72      0.76    167410
# weighted avg       0.87      0.88      0.86    167410
#
# [0]	validation_0-auc:0.69070	validation_1-auc:0.68910
# [1]	validation_0-auc:0.78548	validation_1-auc:0.78346
# [2]	validation_0-auc:0.81101	validation_1-auc:0.80935
# [3]	validation_0-auc:0.81085	validation_1-auc:0.80919
# [4]	validation_0-auc:0.83150	validation_1-auc:0.82983
# [5]	validation_0-auc:0.84704	validation_1-auc:0.84471
# [6]	validation_0-auc:0.87182	validation_1-auc:0.86790
# [7]	validation_0-auc:0.87159	validation_1-auc:0.86769
# [8]	validation_0-auc:0.86999	validation_1-auc:0.86602
# [9]	validation_0-auc:0.86985	validation_1-auc:0.86588
# [10]	validation_0-auc:0.86999	validation_1-auc:0.86597
# [11]	validation_0-auc:0.86989	validation_1-auc:0.86586
# [12]	validation_0-auc:0.87597	validation_1-auc:0.87211
# [13]	validation_0-auc:0.87436	validation_1-auc:0.87049
# [14]	validation_0-auc:0.87922	validation_1-auc:0.87553
# [15]	validation_0-auc:0.87919	validation_1-auc:0.87550
# [16]	validation_0-auc:0.88512	validation_1-auc:0.88167
# [17]	validation_0-auc:0.88510	validation_1-auc:0.88164
# [18]	validation_0-auc:0.89097	validation_1-auc:0.88755
# [19]	validation_0-auc:0.89462	validation_1-auc:0.89129
# [20]	validation_0-auc:0.89747	validation_1-auc:0.89413
# [21]	validation_0-auc:0.89777	validation_1-auc:0.89437
# [22]	validation_0-auc:0.89775	validation_1-auc:0.89435
# [23]	validation_0-auc:0.90040	validation_1-auc:0.89700
# [24]	validation_0-auc:0.90039	validation_1-auc:0.89699
# [25]	validation_0-auc:0.90054	validation_1-auc:0.89730
# [26]	validation_0-auc:0.90054	validation_1-auc:0.89730
# [27]	validation_0-auc:0.90053	validation_1-auc:0.89728
# [28]	validation_0-auc:0.90490	validation_1-auc:0.90155
# [29]	validation_0-auc:0.90489	validation_1-auc:0.90155
# [30]	validation_0-auc:0.90489	validation_1-auc:0.90154
# [31]	validation_0-auc:0.90489	validation_1-auc:0.90154
# [32]	validation_0-auc:0.90925	validation_1-auc:0.90602
# [33]	validation_0-auc:0.90926	validation_1-auc:0.90603
# [34]	validation_0-auc:0.90926	validation_1-auc:0.90603
# [35]	validation_0-auc:0.90926	validation_1-auc:0.90603
# [36]	validation_0-auc:0.91086	validation_1-auc:0.90768
# [37]	validation_0-auc:0.91125	validation_1-auc:0.90806
# [38]	validation_0-auc:0.91443	validation_1-auc:0.91118
# [39]	validation_0-auc:0.91577	validation_1-auc:0.91262
# [40]	validation_0-auc:0.91626	validation_1-auc:0.91316
# [41]	validation_0-auc:0.91717	validation_1-auc:0.91419
# [42]	validation_0-auc:0.91723	validation_1-auc:0.91428
# [43]	validation_0-auc:0.91727	validation_1-auc:0.91432
# [44]	validation_0-auc:0.91727	validation_1-auc:0.91432
# [45]	validation_0-auc:0.91727	validation_1-auc:0.91432
# [46]	validation_0-auc:0.91775	validation_1-auc:0.91481
# [47]	validation_0-auc:0.92219	validation_1-auc:0.91930
# [48]	validation_0-auc:0.92425	validation_1-auc:0.92150
# [49]	validation_0-auc:0.92552	validation_1-auc:0.92278
# [50]	validation_0-auc:0.92551	validation_1-auc:0.92272
# [51]	validation_0-auc:0.92769	validation_1-auc:0.92493
# [52]	validation_0-auc:0.92690	validation_1-auc:0.92411
# [53]	validation_0-auc:0.92738	validation_1-auc:0.92461
# [54]	validation_0-auc:0.92737	validation_1-auc:0.92461
# [55]	validation_0-auc:0.92791	validation_1-auc:0.92522
# [56]	validation_0-auc:0.92856	validation_1-auc:0.92596
# [57]	validation_0-auc:0.92883	validation_1-auc:0.92623
# [58]	validation_0-auc:0.92917	validation_1-auc:0.92648
# [59]	validation_0-auc:0.92917	validation_1-auc:0.92647
# [60]	validation_0-auc:0.92917	validation_1-auc:0.92647
# [61]	validation_0-auc:0.92918	validation_1-auc:0.92649
# [62]	validation_0-auc:0.93000	validation_1-auc:0.92736
# [63]	validation_0-auc:0.93048	validation_1-auc:0.92770
# [64]	validation_0-auc:0.93141	validation_1-auc:0.92872
# [65]	validation_0-auc:0.93141	validation_1-auc:0.92873
# [66]	validation_0-auc:0.93191	validation_1-auc:0.92918
# [67]	validation_0-auc:0.93482	validation_1-auc:0.93218
# [68]	validation_0-auc:0.93482	validation_1-auc:0.93217
# [69]	validation_0-auc:0.93505	validation_1-auc:0.93243
# [70]	validation_0-auc:0.93505	validation_1-auc:0.93244
# [71]	validation_0-auc:0.93619	validation_1-auc:0.93362
# [72]	validation_0-auc:0.93619	validation_1-auc:0.93363
# [73]	validation_0-auc:0.93706	validation_1-auc:0.93458
# [74]	validation_0-auc:0.93724	validation_1-auc:0.93480
# [75]	validation_0-auc:0.93755	validation_1-auc:0.93517
# [76]	validation_0-auc:0.93755	validation_1-auc:0.93517
# [77]	validation_0-auc:0.93776	validation_1-auc:0.93541
# [78]	validation_0-auc:0.93852	validation_1-auc:0.93620
# [79]	validation_0-auc:0.93851	validation_1-auc:0.93620
# [80]	validation_0-auc:0.93851	validation_1-auc:0.93620
# [81]	validation_0-auc:0.93937	validation_1-auc:0.93708
# [82]	validation_0-auc:0.93937	validation_1-auc:0.93712
# [83]	validation_0-auc:0.93966	validation_1-auc:0.93746
# [84]	validation_0-auc:0.93966	validation_1-auc:0.93746
# [85]	validation_0-auc:0.94023	validation_1-auc:0.93806
# [86]	validation_0-auc:0.94023	validation_1-auc:0.93806
# [87]	validation_0-auc:0.94050	validation_1-auc:0.93831
# [88]	validation_0-auc:0.94078	validation_1-auc:0.93857
# [89]	validation_0-auc:0.94068	validation_1-auc:0.93846
# [90]	validation_0-auc:0.94068	validation_1-auc:0.93846
# [91]	validation_0-auc:0.94105	validation_1-auc:0.93882
# [92]	validation_0-auc:0.94105	validation_1-auc:0.93882
# [93]	validation_0-auc:0.94110	validation_1-auc:0.93888
# [94]	validation_0-auc:0.94136	validation_1-auc:0.93915
# [95]	validation_0-auc:0.94163	validation_1-auc:0.93942
# [96]	validation_0-auc:0.94159	validation_1-auc:0.93938
# [97]	validation_0-auc:0.94165	validation_1-auc:0.93947
# [98]	validation_0-auc:0.94170	validation_1-auc:0.93948
# [99]	validation_0-auc:0.94183	validation_1-auc:0.93957
# [100]	validation_0-auc:0.94280	validation_1-auc:0.94058
# [101]	validation_0-auc:0.94295	validation_1-auc:0.94073
# [102]	validation_0-auc:0.94325	validation_1-auc:0.94101
# [103]	validation_0-auc:0.94325	validation_1-auc:0.94098
# [104]	validation_0-auc:0.94334	validation_1-auc:0.94107
# [105]	validation_0-auc:0.94334	validation_1-auc:0.94107
# [106]	validation_0-auc:0.94409	validation_1-auc:0.94182
# [107]	validation_0-auc:0.94410	validation_1-auc:0.94183
# [108]	validation_0-auc:0.94410	validation_1-auc:0.94183
# [109]	validation_0-auc:0.94410	validation_1-auc:0.94183
# [110]	validation_0-auc:0.94435	validation_1-auc:0.94204
# [111]	validation_0-auc:0.94435	validation_1-auc:0.94204
# [112]	validation_0-auc:0.94435	validation_1-auc:0.94204
# [113]	validation_0-auc:0.94449	validation_1-auc:0.94214
# [114]	validation_0-auc:0.94455	validation_1-auc:0.94220
# [115]	validation_0-auc:0.94455	validation_1-auc:0.94220
# [116]	validation_0-auc:0.94465	validation_1-auc:0.94229
# [117]	validation_0-auc:0.94465	validation_1-auc:0.94231
# [118]	validation_0-auc:0.94465	validation_1-auc:0.94231
# [119]	validation_0-auc:0.94481	validation_1-auc:0.94247
# Accuracy Score:
# 0.8768412878561616
# classification REport:
#               precision    recall  f1-score   support
#
#            0       0.81      0.36      0.49     22646
#            1       0.87      0.98      0.92    123982
#            2       0.94      0.84      0.89     20782
#
#     accuracy                           0.88    167410
#    macro avg       0.87      0.73      0.77    167410
# weighted avg       0.87      0.88      0.86    167410
#
# [0]	validation_0-auc:0.68922	validation_1-auc:0.68723
# [1]	validation_0-auc:0.78562	validation_1-auc:0.78339
# [2]	validation_0-auc:0.81091	validation_1-auc:0.80902
# [3]	validation_0-auc:0.81070	validation_1-auc:0.80882
# [4]	validation_0-auc:0.83129	validation_1-auc:0.82963
# [5]	validation_0-auc:0.84705	validation_1-auc:0.84473
# [6]	validation_0-auc:0.87170	validation_1-auc:0.86792
# [7]	validation_0-auc:0.87143	validation_1-auc:0.86766
# [8]	validation_0-auc:0.86987	validation_1-auc:0.86603
# [9]	validation_0-auc:0.86973	validation_1-auc:0.86589
# [10]	validation_0-auc:0.86985	validation_1-auc:0.86596
# [11]	validation_0-auc:0.86976	validation_1-auc:0.86587
# [12]	validation_0-auc:0.87591	validation_1-auc:0.87214
# [13]	validation_0-auc:0.87434	validation_1-auc:0.87052
# [14]	validation_0-auc:0.87914	validation_1-auc:0.87549
# [15]	validation_0-auc:0.87909	validation_1-auc:0.87544
# [16]	validation_0-auc:0.88497	validation_1-auc:0.88162
# [17]	validation_0-auc:0.88495	validation_1-auc:0.88160
# [18]	validation_0-auc:0.89074	validation_1-auc:0.88743
# [19]	validation_0-auc:0.89438	validation_1-auc:0.89111
# [20]	validation_0-auc:0.89711	validation_1-auc:0.89383
# [21]	validation_0-auc:0.89740	validation_1-auc:0.89407
# [22]	validation_0-auc:0.89740	validation_1-auc:0.89406
# [23]	validation_0-auc:0.90006	validation_1-auc:0.89674
# [24]	validation_0-auc:0.90005	validation_1-auc:0.89673
# [25]	validation_0-auc:0.90019	validation_1-auc:0.89701
# [26]	validation_0-auc:0.90018	validation_1-auc:0.89700
# [27]	validation_0-auc:0.90017	validation_1-auc:0.89698
# [28]	validation_0-auc:0.90450	validation_1-auc:0.90122
# [29]	validation_0-auc:0.90450	validation_1-auc:0.90122
# [30]	validation_0-auc:0.90449	validation_1-auc:0.90122
# [31]	validation_0-auc:0.90449	validation_1-auc:0.90121
# [32]	validation_0-auc:0.90882	validation_1-auc:0.90563
# [33]	validation_0-auc:0.90883	validation_1-auc:0.90563
# [34]	validation_0-auc:0.90882	validation_1-auc:0.90563
# [35]	validation_0-auc:0.90882	validation_1-auc:0.90563
# [36]	validation_0-auc:0.91044	validation_1-auc:0.90730
# [37]	validation_0-auc:0.91083	validation_1-auc:0.90767
# [38]	validation_0-auc:0.91399	validation_1-auc:0.91075
# [39]	validation_0-auc:0.91533	validation_1-auc:0.91218
# [40]	validation_0-auc:0.91582	validation_1-auc:0.91273
# [41]	validation_0-auc:0.91676	validation_1-auc:0.91377
# [42]	validation_0-auc:0.91681	validation_1-auc:0.91386
# [43]	validation_0-auc:0.91684	validation_1-auc:0.91389
# [44]	validation_0-auc:0.91684	validation_1-auc:0.91389
# [45]	validation_0-auc:0.91684	validation_1-auc:0.91389
# [46]	validation_0-auc:0.91732	validation_1-auc:0.91437
# [47]	validation_0-auc:0.92171	validation_1-auc:0.91881
# [48]	validation_0-auc:0.92369	validation_1-auc:0.92095
# [49]	validation_0-auc:0.92504	validation_1-auc:0.92230
# [50]	validation_0-auc:0.92504	validation_1-auc:0.92226
# [51]	validation_0-auc:0.92721	validation_1-auc:0.92447
# [52]	validation_0-auc:0.92640	validation_1-auc:0.92364
# [53]	validation_0-auc:0.92687	validation_1-auc:0.92413
# [54]	validation_0-auc:0.92687	validation_1-auc:0.92412
# [55]	validation_0-auc:0.92739	validation_1-auc:0.92468
# [56]	validation_0-auc:0.92805	validation_1-auc:0.92543
# [57]	validation_0-auc:0.92839	validation_1-auc:0.92575
# [58]	validation_0-auc:0.92869	validation_1-auc:0.92598
# [59]	validation_0-auc:0.92869	validation_1-auc:0.92597
# [60]	validation_0-auc:0.92868	validation_1-auc:0.92597
# [61]	validation_0-auc:0.92878	validation_1-auc:0.92609
# [62]	validation_0-auc:0.92959	validation_1-auc:0.92695
# [63]	validation_0-auc:0.93006	validation_1-auc:0.92730
# [64]	validation_0-auc:0.93096	validation_1-auc:0.92831
# [65]	validation_0-auc:0.93096	validation_1-auc:0.92831
# [66]	validation_0-auc:0.93145	validation_1-auc:0.92874
# [67]	validation_0-auc:0.93437	validation_1-auc:0.93174
# [68]	validation_0-auc:0.93437	validation_1-auc:0.93173
# [69]	validation_0-auc:0.93460	validation_1-auc:0.93199
# [70]	validation_0-auc:0.93460	validation_1-auc:0.93199
# [71]	validation_0-auc:0.93577	validation_1-auc:0.93322
# [72]	validation_0-auc:0.93577	validation_1-auc:0.93322
# [73]	validation_0-auc:0.93665	validation_1-auc:0.93416
# [74]	validation_0-auc:0.93685	validation_1-auc:0.93441
# [75]	validation_0-auc:0.93716	validation_1-auc:0.93477
# [76]	validation_0-auc:0.93716	validation_1-auc:0.93477
# [77]	validation_0-auc:0.93738	validation_1-auc:0.93503
# [78]	validation_0-auc:0.93812	validation_1-auc:0.93583
# [79]	validation_0-auc:0.93812	validation_1-auc:0.93583
# [80]	validation_0-auc:0.93812	validation_1-auc:0.93583
# [81]	validation_0-auc:0.93892	validation_1-auc:0.93663
# [82]	validation_0-auc:0.93895	validation_1-auc:0.93668
# [83]	validation_0-auc:0.93926	validation_1-auc:0.93704
# [84]	validation_0-auc:0.93926	validation_1-auc:0.93704
# [85]	validation_0-auc:0.93981	validation_1-auc:0.93763
# [86]	validation_0-auc:0.93981	validation_1-auc:0.93763
# [87]	validation_0-auc:0.94009	validation_1-auc:0.93788
# [88]	validation_0-auc:0.94037	validation_1-auc:0.93814
# [89]	validation_0-auc:0.94024	validation_1-auc:0.93799
# [90]	validation_0-auc:0.94024	validation_1-auc:0.93799
# [91]	validation_0-auc:0.94061	validation_1-auc:0.93836
# [92]	validation_0-auc:0.94062	validation_1-auc:0.93837
# [93]	validation_0-auc:0.94066	validation_1-auc:0.93842
# [94]	validation_0-auc:0.94093	validation_1-auc:0.93871
# [95]	validation_0-auc:0.94122	validation_1-auc:0.93899
# [96]	validation_0-auc:0.94118	validation_1-auc:0.93895
# [97]	validation_0-auc:0.94124	validation_1-auc:0.93903
# [98]	validation_0-auc:0.94128	validation_1-auc:0.93905
# [99]	validation_0-auc:0.94141	validation_1-auc:0.93913
# ...
# [71]	validation_0-auc:0.93342	validation_1-auc:0.93103
# [72]	validation_0-auc:0.93342	validation_1-auc:0.93103
# [73]	validation_0-auc:0.93434	validation_1-auc:0.93203
# [74]	validation_0-auc:0.93454	validation_1-auc:0.93228
# [75]	validation_0-auc:0.93488	validation_1-auc:0.93270
# [76]	validation_0-auc:0.93488	validation_1-auc:0.93270
# [77]	validation_0-auc:0.93513	validation_1-auc:0.93299
# [78]	validation_0-auc:0.93602	validation_1-auc:0.93390
# [79]	validation_0-auc:0.93602	validation_1-auc:0.93390
# [80]	validation_0-auc:0.93602	validation_1-auc:0.93390
# [81]	validation_0-auc:0.93674	validation_1-auc:0.93463
# [82]	validation_0-auc:0.93680	validation_1-auc:0.93470
# [83]	validation_0-auc:0.93707	validation_1-auc:0.93505
# [84]	validation_0-auc:0.93707	validation_1-auc:0.93505
# [85]	validation_0-auc:0.93766	validation_1-auc:0.93565
# [86]	validation_0-auc:0.93766	validation_1-auc:0.93565
# [87]	validation_0-auc:0.93783	validation_1-auc:0.93588
# [88]	validation_0-auc:0.93810	validation_1-auc:0.93615
# [89]	validation_0-auc:0.93802	validation_1-auc:0.93603
# [90]	validation_0-auc:0.93802	validation_1-auc:0.93603
# [91]	validation_0-auc:0.93838	validation_1-auc:0.93640
# [92]	validation_0-auc:0.93838	validation_1-auc:0.93640
# [93]	validation_0-auc:0.93841	validation_1-auc:0.93644
# [94]	validation_0-auc:0.93856	validation_1-auc:0.93661
# [95]	validation_0-auc:0.93885	validation_1-auc:0.93687
# [96]	validation_0-auc:0.93876	validation_1-auc:0.93682
# [97]	validation_0-auc:0.93876	validation_1-auc:0.93682
# [98]	validation_0-auc:0.93880	validation_1-auc:0.93684
# [99]	validation_0-auc:0.93888	validation_1-auc:0.93689
# [100]	validation_0-auc:0.93982	validation_1-auc:0.93790
# [101]	validation_0-auc:0.93996	validation_1-auc:0.93802
# [102]	validation_0-auc:0.94031	validation_1-auc:0.93831
# [103]	validation_0-auc:0.94028	validation_1-auc:0.93827
# [104]	validation_0-auc:0.94038	validation_1-auc:0.93837
# [105]	validation_0-auc:0.94039	validation_1-auc:0.93837
# [106]	validation_0-auc:0.94097	validation_1-auc:0.93897
# [107]	validation_0-auc:0.94097	validation_1-auc:0.93897
# [108]	validation_0-auc:0.94097	validation_1-auc:0.93897
# [109]	validation_0-auc:0.94097	validation_1-auc:0.93897
# Accuracy Score:
# 0.8742369034107879
# classification REport:
#               precision    recall  f1-score   support
#
#            0       0.81      0.34      0.48     22646
#            1       0.87      0.98      0.92    123982
#            2       0.94      0.83      0.88     20782
#
#     accuracy                           0.87    167410
#    macro avg       0.87      0.72      0.76    167410
# weighted avg       0.87      0.87      0.86    167410
# [0]	validation_0-auc:0.68974	validation_1-auc:0.68748
# [1]	validation_0-auc:0.78564	validation_1-auc:0.78331
# [2]	validation_0-auc:0.81115	validation_1-auc:0.80913
# [3]	validation_0-auc:0.81102	validation_1-auc:0.80898
# [4]	validation_0-auc:0.83154	validation_1-auc:0.82969
# [5]	validation_0-auc:0.84698	validation_1-auc:0.84457
# [6]	validation_0-auc:0.87178	validation_1-auc:0.86787
# [7]	validation_0-auc:0.87145	validation_1-auc:0.86757
# [8]	validation_0-auc:0.86980	validation_1-auc:0.86586
# [9]	validation_0-auc:0.86966	validation_1-auc:0.86573
# [10]	validation_0-auc:0.86976	validation_1-auc:0.86579
# [11]	validation_0-auc:0.86966	validation_1-auc:0.86569
# [12]	validation_0-auc:0.87582	validation_1-auc:0.87199
# [13]	validation_0-auc:0.87425	validation_1-auc:0.87043
# [14]	validation_0-auc:0.87904	validation_1-auc:0.87542
# [15]	validation_0-auc:0.87901	validation_1-auc:0.87539
# [16]	validation_0-auc:0.88485	validation_1-auc:0.88150
# [17]	validation_0-auc:0.88481	validation_1-auc:0.88147
# [18]	validation_0-auc:0.89056	validation_1-auc:0.88727
# [19]	validation_0-auc:0.89418	validation_1-auc:0.89098
# [20]	validation_0-auc:0.89687	validation_1-auc:0.89366
# [21]	validation_0-auc:0.89717	validation_1-auc:0.89390
# [22]	validation_0-auc:0.89716	validation_1-auc:0.89389
# [23]	validation_0-auc:0.89978	validation_1-auc:0.89651
# [24]	validation_0-auc:0.89977	validation_1-auc:0.89650
# [25]	validation_0-auc:0.89989	validation_1-auc:0.89675
# [26]	validation_0-auc:0.89989	validation_1-auc:0.89675
# [27]	validation_0-auc:0.89988	validation_1-auc:0.89673
# [28]	validation_0-auc:0.90411	validation_1-auc:0.90088
# [29]	validation_0-auc:0.90411	validation_1-auc:0.90087
# [30]	validation_0-auc:0.90410	validation_1-auc:0.90087
# [31]	validation_0-auc:0.90410	validation_1-auc:0.90087
# [32]	validation_0-auc:0.90840	validation_1-auc:0.90527
# [33]	validation_0-auc:0.90840	validation_1-auc:0.90528
# [34]	validation_0-auc:0.90840	validation_1-auc:0.90528
# [35]	validation_0-auc:0.90840	validation_1-auc:0.90528
# [36]	validation_0-auc:0.91001	validation_1-auc:0.90694
# [37]	validation_0-auc:0.91038	validation_1-auc:0.90729
# [38]	validation_0-auc:0.91349	validation_1-auc:0.91031
# [39]	validation_0-auc:0.91479	validation_1-auc:0.91170
# [40]	validation_0-auc:0.91526	validation_1-auc:0.91222
# [41]	validation_0-auc:0.91623	validation_1-auc:0.91328
# [42]	validation_0-auc:0.91629	validation_1-auc:0.91337
# [43]	validation_0-auc:0.91632	validation_1-auc:0.91340
# [44]	validation_0-auc:0.91632	validation_1-auc:0.91340
# [45]	validation_0-auc:0.91632	validation_1-auc:0.91339
# [46]	validation_0-auc:0.91679	validation_1-auc:0.91388
# [47]	validation_0-auc:0.92128	validation_1-auc:0.91842
# [48]	validation_0-auc:0.92333	validation_1-auc:0.92059
# [49]	validation_0-auc:0.92470	validation_1-auc:0.92193
# [50]	validation_0-auc:0.92465	validation_1-auc:0.92184
# [51]	validation_0-auc:0.92679	validation_1-auc:0.92405
# [52]	validation_0-auc:0.92603	validation_1-auc:0.92326
# [53]	validation_0-auc:0.92650	validation_1-auc:0.92375
# [54]	validation_0-auc:0.92650	validation_1-auc:0.92374
# [55]	validation_0-auc:0.92701	validation_1-auc:0.92429
# [56]	validation_0-auc:0.92765	validation_1-auc:0.92501
# [57]	validation_0-auc:0.92798	validation_1-auc:0.92532
# [58]	validation_0-auc:0.92828	validation_1-auc:0.92557
# [59]	validation_0-auc:0.92828	validation_1-auc:0.92557
# [60]	validation_0-auc:0.92828	validation_1-auc:0.92557
# [61]	validation_0-auc:0.92835	validation_1-auc:0.92566
# [62]	validation_0-auc:0.92917	validation_1-auc:0.92653
# [63]	validation_0-auc:0.92963	validation_1-auc:0.92688
# [64]	validation_0-auc:0.93052	validation_1-auc:0.92786
# [65]	validation_0-auc:0.93052	validation_1-auc:0.92787
# [66]	validation_0-auc:0.93101	validation_1-auc:0.92830
# [67]	validation_0-auc:0.93395	validation_1-auc:0.93133
# [68]	validation_0-auc:0.93395	validation_1-auc:0.93132
# [69]	validation_0-auc:0.93417	validation_1-auc:0.93157
# [70]	validation_0-auc:0.93417	validation_1-auc:0.93157
# [71]	validation_0-auc:0.93534	validation_1-auc:0.93280
# [72]	validation_0-auc:0.93534	validation_1-auc:0.93280
# [73]	validation_0-auc:0.93623	validation_1-auc:0.93376
# [74]	validation_0-auc:0.93641	validation_1-auc:0.93399
# [75]	validation_0-auc:0.93674	validation_1-auc:0.93438
# [76]	validation_0-auc:0.93674	validation_1-auc:0.93438
# [77]	validation_0-auc:0.93697	validation_1-auc:0.93465
# [78]	validation_0-auc:0.93771	validation_1-auc:0.93544
# [79]	validation_0-auc:0.93771	validation_1-auc:0.93544
# [80]	validation_0-auc:0.93771	validation_1-auc:0.93544
# [81]	validation_0-auc:0.93852	validation_1-auc:0.93627
# [82]	validation_0-auc:0.93857	validation_1-auc:0.93634
# [83]	validation_0-auc:0.93885	validation_1-auc:0.93670
# [84]	validation_0-auc:0.93885	validation_1-auc:0.93670
# [85]	validation_0-auc:0.93941	validation_1-auc:0.93728
# [86]	validation_0-auc:0.93941	validation_1-auc:0.93728
# [87]	validation_0-auc:0.93963	validation_1-auc:0.93752
# [88]	validation_0-auc:0.93991	validation_1-auc:0.93778
# [89]	validation_0-auc:0.93980	validation_1-auc:0.93765
# [90]	validation_0-auc:0.93979	validation_1-auc:0.93765
# [91]	validation_0-auc:0.94016	validation_1-auc:0.93802
# [92]	validation_0-auc:0.94016	validation_1-auc:0.93802
# [93]	validation_0-auc:0.94020	validation_1-auc:0.93808
# [94]	validation_0-auc:0.94051	validation_1-auc:0.93837
# [95]	validation_0-auc:0.94079	validation_1-auc:0.93865
# [96]	validation_0-auc:0.94074	validation_1-auc:0.93860
# [97]	validation_0-auc:0.94079	validation_1-auc:0.93867
# [98]	validation_0-auc:0.94084	validation_1-auc:0.93869
# [99]	validation_0-auc:0.94094	validation_1-auc:0.93878
# [100]	validation_0-auc:0.94191	validation_1-auc:0.93979
# [101]	validation_0-auc:0.94205	validation_1-auc:0.93993
# [102]	validation_0-auc:0.94237	validation_1-auc:0.94021
# [103]	validation_0-auc:0.94234	validation_1-auc:0.94018
# [104]	validation_0-auc:0.94243	validation_1-auc:0.94027
# [105]	validation_0-auc:0.94243	validation_1-auc:0.94027
# [106]	validation_0-auc:0.94315	validation_1-auc:0.94098
# [107]	validation_0-auc:0.94316	validation_1-auc:0.94098
# [108]	validation_0-auc:0.94316	validation_1-auc:0.94098
# [109]	validation_0-auc:0.94316	validation_1-auc:0.94098
# [110]	validation_0-auc:0.94340	validation_1-auc:0.94119
# [111]	validation_0-auc:0.94340	validation_1-auc:0.94119
# [112]	validation_0-auc:0.94340	validation_1-auc:0.94119
# [113]	validation_0-auc:0.94354	validation_1-auc:0.94129
# [114]	validation_0-auc:0.94358	validation_1-auc:0.94133
# [115]	validation_0-auc:0.94358	validation_1-auc:0.94133
# [116]	validation_0-auc:0.94368	validation_1-auc:0.94142
# [117]	validation_0-auc:0.94366	validation_1-auc:0.94141
# [118]	validation_0-auc:0.94366	validation_1-auc:0.94141
# [119]	validation_0-auc:0.94381	validation_1-auc:0.94156
# [120]	validation_0-auc:0.94413	validation_1-auc:0.94193
# [121]	validation_0-auc:0.94437	validation_1-auc:0.94213
# [122]	validation_0-auc:0.94437	validation_1-auc:0.94213
# [123]	validation_0-auc:0.94437	validation_1-auc:0.94213
# [124]	validation_0-auc:0.94437	validation_1-auc:0.94213
# [125]	validation_0-auc:0.94438	validation_1-auc:0.94212
# [126]	validation_0-auc:0.94457	validation_1-auc:0.94232
# [127]	validation_0-auc:0.94457	validation_1-auc:0.94232
# [128]	validation_0-auc:0.94464	validation_1-auc:0.94240
# [129]	validation_0-auc:0.94464	validation_1-auc:0.94239
# Accuracy Score:
# 0.8777014515261932
# classification REport:
#               precision    recall  f1-score   support
#
#            0       0.81      0.37      0.50     22646
#            1       0.87      0.98      0.92    123982
#            2       0.94      0.84      0.89     20782
#
#     accuracy                           0.88    167410
#    macro avg       0.87      0.73      0.77    167410
# weighted avg       0.87      0.88      0.86    167410
#
# 100%|██████████| 100/100 [2:11:34<00:00, 78.95s/trial, best loss: -0.8786452422197001]

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'colsample_bytree': 0.7691287679084672, 'gamma': 4.6783838589027145, 'max_depth': 18.0, 'min_Child_weight': 4.0, 'n_estimaotr': 3, 'reg_alpha': 41.0, 'reg_lambda': 0.7565640720749068}

# %%
trials.best_trial
# Out:
# {'state': 2,
#  'tid': 41,
#  'spec': None,
#  'result': {'loss': -0.8786452422197001, 'status': 'ok'},
#  'misc': {'tid': 41,
#   'cmd': ('domain_attachment', 'FMinIter_Domain'),
#   'workdir': None,
#   'idxs': {'colsample_bytree': [41],
#    'gamma': [41],
#    'max_depth': [41],
#    'min_Child_weight': [41],
#    'n_estimaotr': [41],
#    'reg_alpha': [41],
#    'reg_lambda': [41]},
#   'vals': {'colsample_bytree': [0.7691287679084672],
#    'gamma': [4.6783838589027145],
#    'max_depth': [18.0],
#    'min_Child_weight': [4.0],
#    'n_estimaotr': [3],
#    'reg_alpha': [41.0],
#    'reg_lambda': [0.7565640720749068]}},
#  'exp_key': None,
#  'owner': None,
#  'version': 0,
#  'book_time': datetime.datetime(2021, 9, 28, 19, 47, 32, 218000),
#  'refresh_time': datetime.datetime(2021, 9, 28, 19, 48, 23, 453000)}

# %%
model= XGBClassifier(colsample_bytree= 0.7691287679084672, gamma=4.6783838589027145, max_depth= 18, n_estimators= 100,reg_alpha= 41.0,reg_lambda= 0.7565640720749068)

# %%
model.fit(xtrain,ytrain)
ytest_pred= model.predict(xtest)
print(accuracy_score(ytest,ytest_pred))
print(classification_report(ytest,ytest_pred))
# Out:
# [17:16:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9819425362881549
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     22646
#            1       0.99      0.99      0.99    123982
#            2       0.98      0.96      0.97     20782
#
#     accuracy                           0.98    167410
#    macro avg       0.98      0.97      0.97    167410
# weighted avg       0.98      0.98      0.98    167410

# %%
input_test=input("Enter Password to test the stregnthness.")
if input_test=='':
    input_test='abcedefgh'
input_password=np.array([input_test])
feed_pwd= vector.transform(input_password)
pred = model.predict(feed_pwd)
print(pred)
# Out:
# Enter Password to test the stregnthness.testing
# [0]

# %%
#!pip install pickle-mixin
# Out:
# Collecting pickle-mixin
#   Downloading pickle-mixin-1.0.2.tar.gz (5.1 kB)
# Building wheels for collected packages: pickle-mixin
#   Building wheel for pickle-mixin (setup.py): started
#   Building wheel for pickle-mixin (setup.py): finished with status 'done'
#   Created wheel for pickle-mixin: filename=pickle_mixin-1.0.2-py3-none-any.whl size=6008 sha256=8369914d40a4fd9e7e95302d2dc5f6e4321e6d413a15c160abb78a7d1f6cd773
#   Stored in directory: c:\users\sush1\appdata\local\pip\cache\wheels\2a\a4\6c\83bfbc3b94f1bb43d634b07a6a893fd437a45c58b29aea5142
# Successfully built pickle-mixin
# Installing collected packages: pickle-mixin
# Successfully installed pickle-mixin-1.0.2

# %%
import pickle
pickle.dump(model,open('passwordtsrengthXGB.pkl','wb'))
